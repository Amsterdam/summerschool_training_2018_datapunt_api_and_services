# %% [markdown]
# <img src="images/Logo-Gemeente-Amsterdam.png" alt="logo" align="left" position="relative" float="right" width="200"/>

# %% [markdown]
# # Summerschool Training Datapunt API's en Services#
#
# ## https://api.data.amsterdam.nl/api/ ##
#
# - 27 & 28 augustus 2018
# - Eelke Jager
# - e.jager@amsterdam.nl
# - https://www.github.com/lytrix

# %% [markdown]
# ## [Algemene introductie Datapunt](images/20180717_presentatieois-modules.pdf) ##

# %% [markdown]
# ## Wat zijn API's? ##
#
# #### Application Programming Interface
#
# Een API definieert de toegang tot de functionaliteit die er achter schuil gaat. De buitenwereld kent geen details van de functionaliteit of implementatie, maar kan dankzij de API die functionaliteit wel gebruiken. Een voordeel hiervan is dat met een API meerdere implementaties benaderbaar kunnen zijn, zolang deze maar voldoen aan de API.
# https://nl.wikipedia.org/wiki/Application_programming_interface
#
# De meest gebruikte standaard is de REST API.
#
# Andere manieren van services zijn SOAP, RSS of XML/RPC.

# %% [markdown]
# ### Een voorbeeld van een SOAP is onze wetgeving ###
#
# [gebruikersdocumentatie KOOP 2015](http://docplayer.nl/24259054-Basiswettenbestand-gebruikersdocumentatie-web-services-versie-1-0-datum-3-juni-2015.html)
#
# Een voorbeeld van het gebruiken van verkeersborden regelgeving
# - De client website: http://wetten.overheid.nl/BWBR0004825
# - De service: https://repository.officiele-overheidspublicaties.nl/bwb/BWBR0004825/2014-03-20_0/xml/BWBR0004825_2014-03-20_0.xml
# - Het script om hier een csv van te bakken voor het kunnen verwijzen naar de borden en afbeeldingen:
# https://github.com/Amsterdam/mlvb/blob/master/offical_dutch_traffic_signs_by_law/verkeersborden.py

# %% [markdown]
# # Client voorbeelden van de Autocomplete API #
#
# https://api.data.amsterdam.nl/api/swagger/?url=/bag/docs/api-docs/typeahead%3Fformat%3Dopenapi
#
# - https://data.amsterdam.nl
# - http://gebiedinbeeld.amsterdam.nl
# - http://amsterdam.github.io/iot
# - http://amsterdam.github.io/mlvb
# - https://lytrix.github.io/api-examples/autocomplete.html

# %% [markdown]
# Zoals je ziet, gebruik je al snel meerdere api's om de juiste informatie te verkrijgen:
# - Autocomplete API voor een lijst van mogelijkheden terug te krijgen
# - Nummeraanduiding/Openbare ruimte API om 1 object op te vragen waarvan je alle informatie wilt weten.
#
# https://github.com/Lytrix/lytrix.github.io/blob/master/api-examples/autocomplete.html

# %% [markdown]
# # Client voorbeelden van de Geosearch API #
#
# https://api.data.amsterdam.nl/api/swagger/?url=/geosearch/docs/geosearch.yml
#
# De Geosearch API wordt ook gebruikt in verschillende clients (zowel intern als extern) om op basis van een coordinaat de eerst gevonden objecten terug te geven. Deze is naast het klikken in de kaart op data.amsterdam.nl, ook toegepast bij het Container Management Systeem. Dit is gedaan om het dichtstbijzijnde adres op te halen met buurtcode en naam bij een container om de vervuiling door het invoeren van adressen en opmerkingen zoals t/o AH niet meer te hoeven doen.
#
# https://lytrix.github.io/api-examples/geosearch.html

# %% [markdown]
# ## Tutorials ##
# 2 uitgebreide tutorials over REST API's kan je hier lezen:
# - https://www.restapitutorial.com
# - http://www.ict-zelfstudie.nl/rest-02-rest-api-zelfstudie

# %% [markdown]
# 2 belangrijke zaken die je hiervan moet weten zijn:
# - **Uniek identificeerbaar** Elk object (resource) heeft een unieke identificeerbare url (URI genoemd)
# - **Statusloos** Er wordt geen status bijgehouden van meerdere bevragingen van jou als client of applicatie, iedere bevraging heeft een statusloze vorm.
# Daarom moet je zelf bijvoorbeeld vaak zelf eerst een lijst opbouwen van objecten die je wilt zien.
# Je krijgt niet de hele lijst te zien of kan zomaar alles objecten opvragen, tenzij je dit in de API inbouwd.

# %% [markdown]
# ## Wat biedt dit als voordeel? ##
# API's zijn gemaakt om deze altijd 'live' gebruiken.
# Een server achter de API hoeft niets te weten van hoe de weergave eruit moet zien.
# De client applicaties hoeven hebben geen gegevensopslag van deze set gegevens.

# %% [markdown]
# ## JSON ##
#
# JSON als uitwisselformaat wordt het meest gebruikt.
#
# JSON gebruikt alleen {key:value} objecten die als value meerdere {key:value, key value} objecten kunnen bevatten of comma gescheiden lijsten [{...},{...}].
#
# Dus als je een element wilt hebben die 3 lagen diep zit moet je de key namen en/of het nummer weten van het object in de lijst om bij dat gegeven te kunnen komen.
#
# [{'label': 'Straatnamen', 'content': [{'_display': 'Damstraat', 'uri': 'bag/openbareruimte/03630000003189/'}]}]
# Zoals bovenstaand voorbeeld heeft maar 1 object in een lijst. Dit object bevat {label.., content..}
# 'content' bevat wederom een lijst met 1 object {_display, uri}
#
# In het API voorbeeld zullen we hiermee aan de slag gaan.

# %% [markdown]
# # API's met authenticatie #
#
# Voor API's die alleen toegankelijk zijn als je geauthoriseerd bent, zijn deze stappen te doorlopen:
#
# https://amsterdam.github.io/data-processing/extract/download_from_api_with_authentication.html

# %% [markdown]
# Specifiek voor endpoints zijn er al varianten voor geschreven die de uri's al wat verder hebben uitgewerkt:
# - [API BRK Amsterdam](https://amsterdam.github.io/data-processing/extract/download_from_api_brk.html)
# - [API Landelijke KVK](https://amsterdam.github.io/data-processing/extract/download_from_api_kvk.html)

# %% [markdown]
# # Voorbeeld bevraging API en opslaan naar CSV #
#
# Hiervoor gebruiken https://jupyter.org/try met Python 3.
# Via deze link kan je Jupyter of Jupyterhub (als Jupyter overbelast is) in de browser draaien.

# %%
# Laad modules in
import requests
from pprint import pprint

# %%
# Geef zoekopdracht aan de autocomplete
url = 'https://api.data.amsterdam.nl/atlas/typeahead/bag/?q='
query = 'damstraat'

# %%
# Haal data op
data = requests.get(url + query)

# %%
# Laat data zien
print(data)
# Out:
# <Response [200]>

# %%
# Zet de data om naar een Dictonary zodat je de met de data kan werken
data = data.json()
print(data)
# Out:
# [{'label': 'Straatnamen', 'content': [{'_display': 'Damstraat', 'uri': 'bag/openbareruimte/03630000003189/'}]}]

# %%
# Selecteer het eerste item (0) van het lijst object (zie je door de []) en pak daar de 'uri' van het eerste item (0)
uri_eerst_gevonden_object = data[0]['content'][0]['uri']
print(uri_eerst_gevonden_object)
# Out:
# bag/openbareruimte/03630000003189/

# %%
# Bouw de URI als een URL op zodat je de informatie kan ophalen van het gevonden object
base_url = 'https://api.data.amsterdam.nl/'
query2 = base_url + uri_eerst_gevonden_object
print(query2)
# Out:
# https://api.data.amsterdam.nl/bag/openbareruimte/03630000003189/

# %%
# Vraag de data op van bovenstaande URL en toon deze met inspringing
query_openbare_ruimte = requests.get(query2).json()
pprint(query_openbare_ruimte, indent=4)
# Out:
# {   '_display': 'Damstraat',
#     '_links': {   'self': {   'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}},
#     'adressen': {   'count': 56,
#                     'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/?openbare_ruimte=0363300000003189'},
#     'bbox': [121413.439, 487227.734, 121525.669, 487296.556],
#     'begin_geldigheid': '2014-01-10',
#     'bron': None,
#     'dataset': 'bag',
#     'date_modified': '2018-08-22T22:35:29.465596Z',
#     'document_mutatie': '2014-01-10',
#     'document_nummer': 'GV00001729_AC00AC',
#     'einde_geldigheid': None,
#     'geometrie': {   'coordinates': [   [   [   [121465.319, 487255.829],
#                                                 [121462.309, 487257.619],
#                                                 [121449.999, 487264.191],
#                                                 [121413.439, 487283.656],
#                                                 [121415.271, 487288.198],
#                                                 [121418.643, 487296.556],
#                                                 [121447.443, 487278.322],
#                                                 [121449.999, 487276.597],
#                                                 [121488.279, 487255.982],
#                                                 [121491.766, 487254.079],
#                                                 [121522.249, 487237.799],
#                                                 [121525.669, 487238.369],
#                                                 [121518.913, 487229.085],
#                                                 [121517.929, 487227.734],
#                                                 [121486.625, 487244.451],
#                                                 [121483.161, 487246.301],
#                                                 [121465.319, 487255.829]]]],
#                      'type': 'MultiPolygon'},
#     'mutatie_gebruiker': 'DBI',
#     'naam': 'Damstraat',
#     'naam_17_posities': 'DAMSTR',
#     'naam_24_posities': 'Damstraat',
#     'openbare_ruimte_code': '08273',
#     'openbare_ruimte_identificatie': '0363300000003189',
#     'sleutelverzendend': '03630000003189',
#     'status': {'code': '35', 'omschrijving': 'Naamgeving uitgegeven'},
#     'straat_nummer': '',
#     'type': 'Weg',
#     'woonplaats': {   '_display': 'Amsterdam',
#                       '_links': {   'self': {   'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}},
#                       'dataset': 'bag',
#                       'landelijk_id': '3594'}}

# %%
# Vraag de lijst met adressen op die bij deze openbare ruimte horen
query_address_details = requests.get(query_openbare_ruimte['adressen']['href'], params={"detailed":1}).json()
pprint(query_address_details, indent=1)
# Out:
# {'_links': {'next': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/?detailed=1&openbare_ruimte=0363300000003189&page=2'},
#             'previous': {'href': None},
#             'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/?openbare_ruimte=0363300000003189&detailed=1'}},
#  'count': 56,
#  'results': [{'_display': 'Damstraat 2-HL',
#               '_geometrie': {'coordinates': [121421.0, 487278.0],
#                              'type': 'Point'},
#               '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076981/'}},
#               'adres': 'Damstraat 2-HL',
#               'adres_nummer': '',
#               'begin_geldigheid': '1005-01-01',
#               'bouwblok': {'_display': 'YA26',
#                            '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/'}},
#                            'dataset': 'gebieden',
#                            'id': '03630012100692'},
#               'bron': None,
#               'buurt': {'_display': 'Nes e.o. (A00d)',
#                         '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/'}},
#                         'code': '00d',
#                         'dataset': 'gebieden',
#                         'naam': 'Nes e.o.'},
#               'buurtcombinatie': {'_display': 'Burgwallen-Oude Zijde (00)',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}},
#                                   'dataset': 'gebieden',
#                                   'naam': 'Burgwallen-Oude Zijde',
#                                   'vollcode': 'A00'},
#               'dataset': 'bag',
#               'date_modified': '2018-08-22T23:02:15.057854Z',
#               'document_mutatie': '1005-01-01',
#               'document_nummer': 'GV00000402',
#               'einde_geldigheid': None,
#               'gebiedsgerichtwerken': {'_display': 'Centrum-West (DX01)',
#                                        '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}},
#                                        'code': 'DX01',
#                                        'dataset': 'gebieden',
#                                        'naam': 'Centrum-West'},
#               'grootstedelijkgebied': None,
#               'hoofdadres': True,
#               'huisletter': '',
#               'huisnummer': 2,
#               'huisnummer_toevoeging': 'HL',
#               'ligplaats': None,
#               'mutatie_gebruiker': 'DBI',
#               'nummeraanduidingidentificatie': '0363200000076981',
#               'openbare_ruimte': {'_display': 'Damstraat',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}},
#                                   'dataset': 'bag',
#                                   'landelijk_id': '0363300000003189'},
#               'postcode': '1012JM',
#               'sleutelverzendend': '03630000076981',
#               'stadsdeel': {'_display': 'Centrum (A)',
#                             '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}},
#                             'code': 'A',
#                             'dataset': 'gebieden',
#                             'naam': 'Centrum'},
#               'standplaats': None,
#               'status': {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'},
#               'type': 'Verblijfsobject',
#               'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614784/',
#               'woonplaats': {'_display': 'Amsterdam',
#                              '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}},
#                              'dataset': 'bag',
#                              'landelijk_id': '3594'}},
#              {'_display': 'Damstraat 2-HR',
#               '_geometrie': {'coordinates': [121421.0, 487278.0],
#                              'type': 'Point'},
#               '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076982/'}},
#               'adres': 'Damstraat 2-HR',
#               'adres_nummer': '',
#               'begin_geldigheid': '1005-01-01',
#               'bouwblok': {'_display': 'YA26',
#                            '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/'}},
#                            'dataset': 'gebieden',
#                            'id': '03630012100692'},
#               'bron': None,
#               'buurt': {'_display': 'Nes e.o. (A00d)',
#                         '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/'}},
#                         'code': '00d',
#                         'dataset': 'gebieden',
#                         'naam': 'Nes e.o.'},
#               'buurtcombinatie': {'_display': 'Burgwallen-Oude Zijde (00)',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}},
#                                   'dataset': 'gebieden',
#                                   'naam': 'Burgwallen-Oude Zijde',
#                                   'vollcode': 'A00'},
#               'dataset': 'bag',
#               'date_modified': '2018-08-22T23:14:09.272367Z',
#               'document_mutatie': '1005-01-01',
#               'document_nummer': 'GV00000402',
#               'einde_geldigheid': None,
#               'gebiedsgerichtwerken': {'_display': 'Centrum-West (DX01)',
#                                        '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}},
#                                        'code': 'DX01',
#                                        'dataset': 'gebieden',
#                                        'naam': 'Centrum-West'},
#               'grootstedelijkgebied': None,
#               'hoofdadres': True,
#               'huisletter': '',
#               'huisnummer': 2,
#               'huisnummer_toevoeging': 'HR',
#               'ligplaats': None,
#               'mutatie_gebruiker': 'DBI',
#               'nummeraanduidingidentificatie': '0363200000076982',
#               'openbare_ruimte': {'_display': 'Damstraat',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}},
#                                   'dataset': 'bag',
#                                   'landelijk_id': '0363300000003189'},
#               'postcode': '1012JM',
#               'sleutelverzendend': '03630000076982',
#               'stadsdeel': {'_display': 'Centrum (A)',
#                             '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}},
#                             'code': 'A',
#                             'dataset': 'gebieden',
#                             'naam': 'Centrum'},
#               'standplaats': None,
#               'status': {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'},
#               'type': 'Verblijfsobject',
#               'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614785/',
#               'woonplaats': {'_display': 'Amsterdam',
#                              '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}},
#                              'dataset': 'bag',
#                              'landelijk_id': '3594'}},
#              {'_display': 'Damstraat 2A',
#               '_geometrie': {'coordinates': [121423.0, 487276.0],
#                              'type': 'Point'},
#               '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076985/'}},
#               'adres': 'Damstraat 2A',
#               'adres_nummer': '',
#               'begin_geldigheid': '1005-01-01',
#               'bouwblok': {'_display': 'YA26',
#                            '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/'}},
#                            'dataset': 'gebieden',
#                            'id': '03630012100692'},
#               'bron': None,
#               'buurt': {'_display': 'Nes e.o. (A00d)',
#                         '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/'}},
#                         'code': '00d',
#                         'dataset': 'gebieden',
#                         'naam': 'Nes e.o.'},
#               'buurtcombinatie': {'_display': 'Burgwallen-Oude Zijde (00)',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}},
#                                   'dataset': 'gebieden',
#                                   'naam': 'Burgwallen-Oude Zijde',
#                                   'vollcode': 'A00'},
#               'dataset': 'bag',
#               'date_modified': '2018-08-22T23:05:14.573148Z',
#               'document_mutatie': '1005-01-01',
#               'document_nummer': 'GV00000402',
#               'einde_geldigheid': None,
#               'gebiedsgerichtwerken': {'_display': 'Centrum-West (DX01)',
#                                        '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}},
#                                        'code': 'DX01',
#                                        'dataset': 'gebieden',
#                                        'naam': 'Centrum-West'},
#               'grootstedelijkgebied': None,
#               'hoofdadres': True,
#               'huisletter': 'A',
#               'huisnummer': 2,
#               'huisnummer_toevoeging': '',
#               'ligplaats': None,
#               'mutatie_gebruiker': 'DBI',
#               'nummeraanduidingidentificatie': '0363200000076985',
#               'openbare_ruimte': {'_display': 'Damstraat',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}},
#                                   'dataset': 'bag',
#                                   'landelijk_id': '0363300000003189'},
#               'postcode': '1012JM',
#               'sleutelverzendend': '03630000076985',
#               'stadsdeel': {'_display': 'Centrum (A)',
#                             '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}},
#                             'code': 'A',
#                             'dataset': 'gebieden',
#                             'naam': 'Centrum'},
#               'standplaats': None,
#               'status': {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'},
#               'type': 'Verblijfsobject',
#               'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614787/',
#               'woonplaats': {'_display': 'Amsterdam',
#                              '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}},
#                              'dataset': 'bag',
#                              'landelijk_id': '3594'}},
#              {'_display': 'Damstraat 3',
#               '_geometrie': {'coordinates': [121445.0, 487283.0],
#                              'type': 'Point'},
#               '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076986/'}},
#               'adres': 'Damstraat 3',
#               'adres_nummer': '',
#               'begin_geldigheid': '1005-01-01',
#               'bouwblok': {'_display': 'YA23',
#                            '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012095692/'}},
#                            'dataset': 'gebieden',
#                            'id': '03630012095692'},
#               'bron': None,
#               'buurt': {'_display': 'Oude Kerk e.o. (A00b)',
#                         '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/'}},
#                         'code': '00b',
#                         'dataset': 'gebieden',
#                         'naam': 'Oude Kerk e.o.'},
#               'buurtcombinatie': {'_display': 'Burgwallen-Oude Zijde (00)',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}},
#                                   'dataset': 'gebieden',
#                                   'naam': 'Burgwallen-Oude Zijde',
#                                   'vollcode': 'A00'},
#               'dataset': 'bag',
#               'date_modified': '2018-08-22T23:02:15.063193Z',
#               'document_mutatie': '1005-01-01',
#               'document_nummer': 'GV00000402',
#               'einde_geldigheid': None,
#               'gebiedsgerichtwerken': {'_display': 'Centrum-West (DX01)',
#                                        '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}},
#                                        'code': 'DX01',
#                                        'dataset': 'gebieden',
#                                        'naam': 'Centrum-West'},
#               'grootstedelijkgebied': None,
#               'hoofdadres': True,
#               'huisletter': '',
#               'huisnummer': 3,
#               'huisnummer_toevoeging': '',
#               'ligplaats': None,
#               'mutatie_gebruiker': 'DBI',
#               'nummeraanduidingidentificatie': '0363200000076986',
#               'openbare_ruimte': {'_display': 'Damstraat',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}},
#                                   'dataset': 'bag',
#                                   'landelijk_id': '0363300000003189'},
#               'postcode': '1012JL',
#               'sleutelverzendend': '03630000076986',
#               'stadsdeel': {'_display': 'Centrum (A)',
#                             '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}},
#                             'code': 'A',
#                             'dataset': 'gebieden',
#                             'naam': 'Centrum'},
#               'standplaats': None,
#               'status': {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'},
#               'type': 'Verblijfsobject',
#               'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614788/',
#               'woonplaats': {'_display': 'Amsterdam',
#                              '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}},
#                              'dataset': 'bag',
#                              'landelijk_id': '3594'}},
#              {'_display': 'Damstraat 4',
#               '_geometrie': {'coordinates': [121428.0, 487272.0],
#                              'type': 'Point'},
#               '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076987/'}},
#               'adres': 'Damstraat 4',
#               'adres_nummer': '',
#               'begin_geldigheid': '1005-01-01',
#               'bouwblok': {'_display': 'YA26',
#                            '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/'}},
#                            'dataset': 'gebieden',
#                            'id': '03630012100692'},
#               'bron': None,
#               'buurt': {'_display': 'Nes e.o. (A00d)',
#                         '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/'}},
#                         'code': '00d',
#                         'dataset': 'gebieden',
#                         'naam': 'Nes e.o.'},
#               'buurtcombinatie': {'_display': 'Burgwallen-Oude Zijde (00)',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}},
#                                   'dataset': 'gebieden',
#                                   'naam': 'Burgwallen-Oude Zijde',
#                                   'vollcode': 'A00'},
#               'dataset': 'bag',
#               'date_modified': '2018-08-22T23:08:11.449480Z',
#               'document_mutatie': '1005-01-01',
#               'document_nummer': 'GV00000402',
#               'einde_geldigheid': None,
#               'gebiedsgerichtwerken': {'_display': 'Centrum-West (DX01)',
#                                        '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}},
#                                        'code': 'DX01',
#                                        'dataset': 'gebieden',
#                                        'naam': 'Centrum-West'},
#               'grootstedelijkgebied': None,
#               'hoofdadres': True,
#               'huisletter': '',
#               'huisnummer': 4,
#               'huisnummer_toevoeging': '',
#               'ligplaats': None,
#               'mutatie_gebruiker': 'DBI',
#               'nummeraanduidingidentificatie': '0363200000076987',
#               'openbare_ruimte': {'_display': 'Damstraat',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}},
#                                   'dataset': 'bag',
#                                   'landelijk_id': '0363300000003189'},
#               'postcode': '1012JM',
#               'sleutelverzendend': '03630000076987',
#               'stadsdeel': {'_display': 'Centrum (A)',
#                             '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}},
#                             'code': 'A',
#                             'dataset': 'gebieden',
#                             'naam': 'Centrum'},
#               'standplaats': None,
#               'status': {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'},
#               'type': 'Verblijfsobject',
#               'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614789/',
#               'woonplaats': {'_display': 'Amsterdam',
#                              '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}},
#                              'dataset': 'bag',
#                              'landelijk_id': '3594'}},
#              {'_display': 'Damstraat 5',
#               '_geometrie': {'coordinates': [121454.0, 487278.0],
#                              'type': 'Point'},
#               '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076988/'}},
#               'adres': 'Damstraat 5',
#               'adres_nummer': '',
#               'begin_geldigheid': '1005-01-01',
#               'bouwblok': {'_display': 'YA23',
#                            '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012095692/'}},
#                            'dataset': 'gebieden',
#                            'id': '03630012095692'},
#               'bron': None,
#               'buurt': {'_display': 'Oude Kerk e.o. (A00b)',
#                         '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/'}},
#                         'code': '00b',
#                         'dataset': 'gebieden',
#                         'naam': 'Oude Kerk e.o.'},
#               'buurtcombinatie': {'_display': 'Burgwallen-Oude Zijde (00)',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}},
#                                   'dataset': 'gebieden',
#                                   'naam': 'Burgwallen-Oude Zijde',
#                                   'vollcode': 'A00'},
#               'dataset': 'bag',
#               'date_modified': '2018-08-22T23:02:15.065902Z',
#               'document_mutatie': '1005-01-01',
#               'document_nummer': 'GV00000402',
#               'einde_geldigheid': None,
#               'gebiedsgerichtwerken': {'_display': 'Centrum-West (DX01)',
#                                        '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}},
#                                        'code': 'DX01',
#                                        'dataset': 'gebieden',
#                                        'naam': 'Centrum-West'},
#               'grootstedelijkgebied': None,
#               'hoofdadres': True,
#               'huisletter': '',
#               'huisnummer': 5,
#               'huisnummer_toevoeging': '',
#               'ligplaats': None,
#               'mutatie_gebruiker': 'DBI',
#               'nummeraanduidingidentificatie': '0363200000076988',
#               'openbare_ruimte': {'_display': 'Damstraat',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}},
#                                   'dataset': 'bag',
#                                   'landelijk_id': '0363300000003189'},
#               'postcode': '1012JL',
#               'sleutelverzendend': '03630000076988',
#               'stadsdeel': {'_display': 'Centrum (A)',
#                             '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}},
#                             'code': 'A',
#                             'dataset': 'gebieden',
#                             'naam': 'Centrum'},
#               'standplaats': None,
#               'status': {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'},
#               'type': 'Verblijfsobject',
#               'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614790/',
#               'woonplaats': {'_display': 'Amsterdam',
#                              '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}},
#                              'dataset': 'bag',
#                              'landelijk_id': '3594'}},
#              {'_display': 'Damstraat 6',
#               '_geometrie': {'coordinates': [121431.0, 487271.0],
#                              'type': 'Point'},
#               '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076989/'}},
#               'adres': 'Damstraat 6',
#               'adres_nummer': '',
#               'begin_geldigheid': '2009-12-07',
#               'bouwblok': {'_display': 'YA26',
#                            '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/'}},
#                            'dataset': 'gebieden',
#                            'id': '03630012100692'},
#               'bron': None,
#               'buurt': {'_display': 'Nes e.o. (A00d)',
#                         '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/'}},
#                         'code': '00d',
#                         'dataset': 'gebieden',
#                         'naam': 'Nes e.o.'},
#               'buurtcombinatie': {'_display': 'Burgwallen-Oude Zijde (00)',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}},
#                                   'dataset': 'gebieden',
#                                   'naam': 'Burgwallen-Oude Zijde',
#                                   'vollcode': 'A00'},
#               'dataset': 'bag',
#               'date_modified': '2018-08-22T23:02:15.068531Z',
#               'document_mutatie': '2009-12-07',
#               'document_nummer': 'GV00000402',
#               'einde_geldigheid': None,
#               'gebiedsgerichtwerken': {'_display': 'Centrum-West (DX01)',
#                                        '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}},
#                                        'code': 'DX01',
#                                        'dataset': 'gebieden',
#                                        'naam': 'Centrum-West'},
#               'grootstedelijkgebied': None,
#               'hoofdadres': True,
#               'huisletter': '',
#               'huisnummer': 6,
#               'huisnummer_toevoeging': '',
#               'ligplaats': None,
#               'mutatie_gebruiker': 'DBI',
#               'nummeraanduidingidentificatie': '0363200000076989',
#               'openbare_ruimte': {'_display': 'Damstraat',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}},
#                                   'dataset': 'bag',
#                                   'landelijk_id': '0363300000003189'},
#               'postcode': '1012JM',
#               'sleutelverzendend': '03630000076989',
#               'stadsdeel': {'_display': 'Centrum (A)',
#                             '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}},
#                             'code': 'A',
#                             'dataset': 'gebieden',
#                             'naam': 'Centrum'},
#               'standplaats': None,
#               'status': {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'},
#               'type': 'Verblijfsobject',
#               'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614791/',
#               'woonplaats': {'_display': 'Amsterdam',
#                              '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}},
#                              'dataset': 'bag',
#                              'landelijk_id': '3594'}},
#              {'_display': 'Damstraat 7',
#               '_geometrie': {'coordinates': [121463.0, 487274.0],
#                              'type': 'Point'},
#               '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076990/'}},
#               'adres': 'Damstraat 7',
#               'adres_nummer': '',
#               'begin_geldigheid': '1005-01-01',
#               'bouwblok': {'_display': 'YA23',
#                            '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012095692/'}},
#                            'dataset': 'gebieden',
#                            'id': '03630012095692'},
#               'bron': None,
#               'buurt': {'_display': 'Oude Kerk e.o. (A00b)',
#                         '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/'}},
#                         'code': '00b',
#                         'dataset': 'gebieden',
#                         'naam': 'Oude Kerk e.o.'},
#               'buurtcombinatie': {'_display': 'Burgwallen-Oude Zijde (00)',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}},
#                                   'dataset': 'gebieden',
#                                   'naam': 'Burgwallen-Oude Zijde',
#                                   'vollcode': 'A00'},
#               'dataset': 'bag',
#               'date_modified': '2018-08-22T23:05:14.575977Z',
#               'document_mutatie': '1005-01-01',
#               'document_nummer': 'GV00000402',
#               'einde_geldigheid': None,
#               'gebiedsgerichtwerken': {'_display': 'Centrum-West (DX01)',
#                                        '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}},
#                                        'code': 'DX01',
#                                        'dataset': 'gebieden',
#                                        'naam': 'Centrum-West'},
#               'grootstedelijkgebied': None,
#               'hoofdadres': True,
#               'huisletter': '',
#               'huisnummer': 7,
#               'huisnummer_toevoeging': '',
#               'ligplaats': None,
#               'mutatie_gebruiker': 'DBI',
#               'nummeraanduidingidentificatie': '0363200000076990',
#               'openbare_ruimte': {'_display': 'Damstraat',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}},
#                                   'dataset': 'bag',
#                                   'landelijk_id': '0363300000003189'},
#               'postcode': '1012JL',
#               'sleutelverzendend': '03630000076990',
#               'stadsdeel': {'_display': 'Centrum (A)',
#                             '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}},
#                             'code': 'A',
#                             'dataset': 'gebieden',
#                             'naam': 'Centrum'},
#               'standplaats': None,
#               'status': {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'},
#               'type': 'Verblijfsobject',
#               'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614792/',
#               'woonplaats': {'_display': 'Amsterdam',
#                              '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}},
#                              'dataset': 'bag',
#                              'landelijk_id': '3594'}},
#              {'_display': 'Damstraat 9',
#               '_geometrie': {'coordinates': [121470.0, 487270.0],
#                              'type': 'Point'},
#               '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076992/'}},
#               'adres': 'Damstraat 9',
#               'adres_nummer': '',
#               'begin_geldigheid': '1980-01-01',
#               'bouwblok': {'_display': 'YA22',
#                            '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/'}},
#                            'dataset': 'gebieden',
#                            'id': '03630012099548'},
#               'bron': None,
#               'buurt': {'_display': 'Oude Kerk e.o. (A00b)',
#                         '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/'}},
#                         'code': '00b',
#                         'dataset': 'gebieden',
#                         'naam': 'Oude Kerk e.o.'},
#               'buurtcombinatie': {'_display': 'Burgwallen-Oude Zijde (00)',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}},
#                                   'dataset': 'gebieden',
#                                   'naam': 'Burgwallen-Oude Zijde',
#                                   'vollcode': 'A00'},
#               'dataset': 'bag',
#               'date_modified': '2018-08-22T23:08:11.452084Z',
#               'document_mutatie': '1980-01-01',
#               'document_nummer': 'GV00000402',
#               'einde_geldigheid': None,
#               'gebiedsgerichtwerken': {'_display': 'Centrum-West (DX01)',
#                                        '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}},
#                                        'code': 'DX01',
#                                        'dataset': 'gebieden',
#                                        'naam': 'Centrum-West'},
#               'grootstedelijkgebied': None,
#               'hoofdadres': True,
#               'huisletter': '',
#               'huisnummer': 9,
#               'huisnummer_toevoeging': '',
#               'ligplaats': None,
#               'mutatie_gebruiker': 'DBI',
#               'nummeraanduidingidentificatie': '0363200000076992',
#               'openbare_ruimte': {'_display': 'Damstraat',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}},
#                                   'dataset': 'bag',
#                                   'landelijk_id': '0363300000003189'},
#               'postcode': '1012JL',
#               'sleutelverzendend': '03630000076992',
#               'stadsdeel': {'_display': 'Centrum (A)',
#                             '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}},
#                             'code': 'A',
#                             'dataset': 'gebieden',
#                             'naam': 'Centrum'},
#               'standplaats': None,
#               'status': {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'},
#               'type': 'Verblijfsobject',
#               'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630001015263/',
#               'woonplaats': {'_display': 'Amsterdam',
#                              '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}},
#                              'dataset': 'bag',
#                              'landelijk_id': '3594'}},
#              {'_display': 'Damstraat 11',
#               '_geometrie': {'coordinates': [121475.0, 487267.0],
#                              'type': 'Point'},
#               '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076994/'}},
#               'adres': 'Damstraat 11',
#               'adres_nummer': '',
#               'begin_geldigheid': '1980-01-01',
#               'bouwblok': {'_display': 'YA22',
#                            '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/'}},
#                            'dataset': 'gebieden',
#                            'id': '03630012099548'},
#               'bron': None,
#               'buurt': {'_display': 'Oude Kerk e.o. (A00b)',
#                         '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/'}},
#                         'code': '00b',
#                         'dataset': 'gebieden',
#                         'naam': 'Oude Kerk e.o.'},
#               'buurtcombinatie': {'_display': 'Burgwallen-Oude Zijde (00)',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}},
#                                   'dataset': 'gebieden',
#                                   'naam': 'Burgwallen-Oude Zijde',
#                                   'vollcode': 'A00'},
#               'dataset': 'bag',
#               'date_modified': '2018-08-22T23:08:11.454847Z',
#               'document_mutatie': '1980-01-01',
#               'document_nummer': 'GV00000402',
#               'einde_geldigheid': None,
#               'gebiedsgerichtwerken': {'_display': 'Centrum-West (DX01)',
#                                        '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}},
#                                        'code': 'DX01',
#                                        'dataset': 'gebieden',
#                                        'naam': 'Centrum-West'},
#               'grootstedelijkgebied': None,
#               'hoofdadres': True,
#               'huisletter': '',
#               'huisnummer': 11,
#               'huisnummer_toevoeging': '',
#               'ligplaats': None,
#               'mutatie_gebruiker': 'DBI',
#               'nummeraanduidingidentificatie': '0363200000076994',
#               'openbare_ruimte': {'_display': 'Damstraat',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}},
#                                   'dataset': 'bag',
#                                   'landelijk_id': '0363300000003189'},
#               'postcode': '1012JL',
#               'sleutelverzendend': '03630000076994',
#               'stadsdeel': {'_display': 'Centrum (A)',
#                             '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}},
#                             'code': 'A',
#                             'dataset': 'gebieden',
#                             'naam': 'Centrum'},
#               'standplaats': None,
#               'status': {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'},
#               'type': 'Verblijfsobject',
#               'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630001015264/',
#               'woonplaats': {'_display': 'Amsterdam',
#                              '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}},
#                              'dataset': 'bag',
#                              'landelijk_id': '3594'}},
#              {'_display': 'Damstraat 12',
#               '_geometrie': {'coordinates': [121442.0, 487267.0],
#                              'type': 'Point'},
#               '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076995/'}},
#               'adres': 'Damstraat 12',
#               'adres_nummer': '',
#               'begin_geldigheid': '1005-01-01',
#               'bouwblok': {'_display': 'YA26',
#                            '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/'}},
#                            'dataset': 'gebieden',
#                            'id': '03630012100692'},
#               'bron': None,
#               'buurt': {'_display': 'Nes e.o. (A00d)',
#                         '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/'}},
#                         'code': '00d',
#                         'dataset': 'gebieden',
#                         'naam': 'Nes e.o.'},
#               'buurtcombinatie': {'_display': 'Burgwallen-Oude Zijde (00)',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}},
#                                   'dataset': 'gebieden',
#                                   'naam': 'Burgwallen-Oude Zijde',
#                                   'vollcode': 'A00'},
#               'dataset': 'bag',
#               'date_modified': '2018-08-22T23:17:06.864934Z',
#               'document_mutatie': '1005-01-01',
#               'document_nummer': 'GV00000402',
#               'einde_geldigheid': None,
#               'gebiedsgerichtwerken': {'_display': 'Centrum-West (DX01)',
#                                        '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}},
#                                        'code': 'DX01',
#                                        'dataset': 'gebieden',
#                                        'naam': 'Centrum-West'},
#               'grootstedelijkgebied': None,
#               'hoofdadres': True,
#               'huisletter': '',
#               'huisnummer': 12,
#               'huisnummer_toevoeging': '',
#               'ligplaats': None,
#               'mutatie_gebruiker': 'DBI',
#               'nummeraanduidingidentificatie': '0363200000076995',
#               'openbare_ruimte': {'_display': 'Damstraat',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}},
#                                   'dataset': 'bag',
#                                   'landelijk_id': '0363300000003189'},
#               'postcode': '1012JM',
#               'sleutelverzendend': '03630000076995',
#               'stadsdeel': {'_display': 'Centrum (A)',
#                             '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}},
#                             'code': 'A',
#                             'dataset': 'gebieden',
#                             'naam': 'Centrum'},
#               'standplaats': None,
#               'status': {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'},
#               'type': 'Verblijfsobject',
#               'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614794/',
#               'woonplaats': {'_display': 'Amsterdam',
#                              '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}},
#                              'dataset': 'bag',
#                              'landelijk_id': '3594'}},
#              {'_display': 'Damstraat 13',
#               '_geometrie': {'coordinates': [121479.0, 487265.0],
#                              'type': 'Point'},
#               '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076997/'}},
#               'adres': 'Damstraat 13',
#               'adres_nummer': '',
#               'begin_geldigheid': '1980-01-01',
#               'bouwblok': {'_display': 'YA22',
#                            '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/'}},
#                            'dataset': 'gebieden',
#                            'id': '03630012099548'},
#               'bron': None,
#               'buurt': {'_display': 'Oude Kerk e.o. (A00b)',
#                         '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/'}},
#                         'code': '00b',
#                         'dataset': 'gebieden',
#                         'naam': 'Oude Kerk e.o.'},
#               'buurtcombinatie': {'_display': 'Burgwallen-Oude Zijde (00)',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}},
#                                   'dataset': 'gebieden',
#                                   'naam': 'Burgwallen-Oude Zijde',
#                                   'vollcode': 'A00'},
#               'dataset': 'bag',
#               'date_modified': '2018-08-22T22:56:03.067623Z',
#               'document_mutatie': '1980-01-01',
#               'document_nummer': 'GV00000402',
#               'einde_geldigheid': None,
#               'gebiedsgerichtwerken': {'_display': 'Centrum-West (DX01)',
#                                        '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}},
#                                        'code': 'DX01',
#                                        'dataset': 'gebieden',
#                                        'naam': 'Centrum-West'},
#               'grootstedelijkgebied': None,
#               'hoofdadres': True,
#               'huisletter': '',
#               'huisnummer': 13,
#               'huisnummer_toevoeging': '',
#               'ligplaats': None,
#               'mutatie_gebruiker': 'DBI',
#               'nummeraanduidingidentificatie': '0363200000076997',
#               'openbare_ruimte': {'_display': 'Damstraat',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}},
#                                   'dataset': 'bag',
#                                   'landelijk_id': '0363300000003189'},
#               'postcode': '1012JL',
#               'sleutelverzendend': '03630000076997',
#               'stadsdeel': {'_display': 'Centrum (A)',
#                             '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}},
#                             'code': 'A',
#                             'dataset': 'gebieden',
#                             'naam': 'Centrum'},
#               'standplaats': None,
#               'status': {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'},
#               'type': 'Verblijfsobject',
#               'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630001015265/',
#               'woonplaats': {'_display': 'Amsterdam',
#                              '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}},
#                              'dataset': 'bag',
#                              'landelijk_id': '3594'}},
#              {'_display': 'Damstraat 15',
#               '_geometrie': {'coordinates': [121486.0, 487260.0],
#                              'type': 'Point'},
#               '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076999/'}},
#               'adres': 'Damstraat 15',
#               'adres_nummer': '',
#               'begin_geldigheid': '1980-01-01',
#               'bouwblok': {'_display': 'YA22',
#                            '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/'}},
#                            'dataset': 'gebieden',
#                            'id': '03630012099548'},
#               'bron': None,
#               'buurt': {'_display': 'Oude Kerk e.o. (A00b)',
#                         '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/'}},
#                         'code': '00b',
#                         'dataset': 'gebieden',
#                         'naam': 'Oude Kerk e.o.'},
#               'buurtcombinatie': {'_display': 'Burgwallen-Oude Zijde (00)',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}},
#                                   'dataset': 'gebieden',
#                                   'naam': 'Burgwallen-Oude Zijde',
#                                   'vollcode': 'A00'},
#               'dataset': 'bag',
#               'date_modified': '2018-08-22T23:08:11.457705Z',
#               'document_mutatie': '1980-01-01',
#               'document_nummer': 'GV00000402',
#               'einde_geldigheid': None,
#               'gebiedsgerichtwerken': {'_display': 'Centrum-West (DX01)',
#                                        '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}},
#                                        'code': 'DX01',
#                                        'dataset': 'gebieden',
#                                        'naam': 'Centrum-West'},
#               'grootstedelijkgebied': None,
#               'hoofdadres': True,
#               'huisletter': '',
#               'huisnummer': 15,
#               'huisnummer_toevoeging': '',
#               'ligplaats': None,
#               'mutatie_gebruiker': 'DBI',
#               'nummeraanduidingidentificatie': '0363200000076999',
#               'openbare_ruimte': {'_display': 'Damstraat',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}},
#                                   'dataset': 'bag',
#                                   'landelijk_id': '0363300000003189'},
#               'postcode': '1012JL',
#               'sleutelverzendend': '03630000076999',
#               'stadsdeel': {'_display': 'Centrum (A)',
#                             '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}},
#                             'code': 'A',
#                             'dataset': 'gebieden',
#                             'naam': 'Centrum'},
#               'standplaats': None,
#               'status': {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'},
#               'type': 'Verblijfsobject',
#               'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630001015266/',
#               'woonplaats': {'_display': 'Amsterdam',
#                              '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}},
#                              'dataset': 'bag',
#                              'landelijk_id': '3594'}},
#              {'_display': 'Damstraat 16-H',
#               '_geometrie': {'coordinates': [121451.0, 487261.0],
#                              'type': 'Point'},
#               '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077000/'}},
#               'adres': 'Damstraat 16-H',
#               'adres_nummer': '',
#               'begin_geldigheid': '1005-01-01',
#               'bouwblok': {'_display': 'YA26',
#                            '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/'}},
#                            'dataset': 'gebieden',
#                            'id': '03630012100692'},
#               'bron': None,
#               'buurt': {'_display': 'Nes e.o. (A00d)',
#                         '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/'}},
#                         'code': '00d',
# ...
#               'grootstedelijkgebied': None,
#               'hoofdadres': True,
#               'huisletter': '',
#               'huisnummer': 23,
#               'huisnummer_toevoeging': '',
#               'ligplaats': None,
#               'mutatie_gebruiker': 'DBI',
#               'nummeraanduidingidentificatie': '0363200000077011',
#               'openbare_ruimte': {'_display': 'Damstraat',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}},
#                                   'dataset': 'bag',
#                                   'landelijk_id': '0363300000003189'},
#               'postcode': '1012JL',
#               'sleutelverzendend': '03630000077011',
#               'stadsdeel': {'_display': 'Centrum (A)',
#                             '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}},
#                             'code': 'A',
#                             'dataset': 'gebieden',
#                             'naam': 'Centrum'},
#               'standplaats': None,
#               'status': {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'},
#               'type': 'Verblijfsobject',
#               'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630001015270/',
#               'woonplaats': {'_display': 'Amsterdam',
#                              '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}},
#                              'dataset': 'bag',
#                              'landelijk_id': '3594'}},
#              {'_display': 'Damstraat 25',
#               '_geometrie': {'coordinates': [121511.0, 487248.0],
#                              'type': 'Point'},
#               '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077013/'}},
#               'adres': 'Damstraat 25',
#               'adres_nummer': '',
#               'begin_geldigheid': '1980-01-01',
#               'bouwblok': {'_display': 'YA22',
#                            '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/'}},
#                            'dataset': 'gebieden',
#                            'id': '03630012099548'},
#               'bron': None,
#               'buurt': {'_display': 'Oude Kerk e.o. (A00b)',
#                         '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/'}},
#                         'code': '00b',
#                         'dataset': 'gebieden',
#                         'naam': 'Oude Kerk e.o.'},
#               'buurtcombinatie': {'_display': 'Burgwallen-Oude Zijde (00)',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}},
#                                   'dataset': 'gebieden',
#                                   'naam': 'Burgwallen-Oude Zijde',
#                                   'vollcode': 'A00'},
#               'dataset': 'bag',
#               'date_modified': '2018-08-22T23:02:15.073726Z',
#               'document_mutatie': '1980-01-01',
#               'document_nummer': 'GV00000402',
#               'einde_geldigheid': None,
#               'gebiedsgerichtwerken': {'_display': 'Centrum-West (DX01)',
#                                        '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}},
#                                        'code': 'DX01',
#                                        'dataset': 'gebieden',
#                                        'naam': 'Centrum-West'},
#               'grootstedelijkgebied': None,
#               'hoofdadres': True,
#               'huisletter': '',
#               'huisnummer': 25,
#               'huisnummer_toevoeging': '',
#               'ligplaats': None,
#               'mutatie_gebruiker': 'DBI',
#               'nummeraanduidingidentificatie': '0363200000077013',
#               'openbare_ruimte': {'_display': 'Damstraat',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}},
#                                   'dataset': 'bag',
#                                   'landelijk_id': '0363300000003189'},
#               'postcode': '1012JL',
#               'sleutelverzendend': '03630000077013',
#               'stadsdeel': {'_display': 'Centrum (A)',
#                             '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}},
#                             'code': 'A',
#                             'dataset': 'gebieden',
#                             'naam': 'Centrum'},
#               'standplaats': None,
#               'status': {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'},
#               'type': 'Verblijfsobject',
#               'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630001015271/',
#               'woonplaats': {'_display': 'Amsterdam',
#                              '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}},
#                              'dataset': 'bag',
#                              'landelijk_id': '3594'}},
#              {'_display': 'Damstraat 26-H',
#               '_geometrie': {'coordinates': [121478.0, 487246.0],
#                              'type': 'Point'},
#               '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077014/'}},
#               'adres': 'Damstraat 26-H',
#               'adres_nummer': '',
#               'begin_geldigheid': '2014-03-15',
#               'bouwblok': {'_display': 'YA27',
#                            '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099976/'}},
#                            'dataset': 'gebieden',
#                            'id': '03630012099976'},
#               'bron': None,
#               'buurt': {'_display': 'Nes e.o. (A00d)',
#                         '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/'}},
#                         'code': '00d',
#                         'dataset': 'gebieden',
#                         'naam': 'Nes e.o.'},
#               'buurtcombinatie': {'_display': 'Burgwallen-Oude Zijde (00)',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}},
#                                   'dataset': 'gebieden',
#                                   'naam': 'Burgwallen-Oude Zijde',
#                                   'vollcode': 'A00'},
#               'dataset': 'bag',
#               'date_modified': '2018-08-22T22:58:22.714234Z',
#               'document_mutatie': '2014-03-15',
#               'document_nummer': 'SA00003980_RB02OR',
#               'einde_geldigheid': None,
#               'gebiedsgerichtwerken': {'_display': 'Centrum-West (DX01)',
#                                        '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}},
#                                        'code': 'DX01',
#                                        'dataset': 'gebieden',
#                                        'naam': 'Centrum-West'},
#               'grootstedelijkgebied': None,
#               'hoofdadres': True,
#               'huisletter': '',
#               'huisnummer': 26,
#               'huisnummer_toevoeging': 'H',
#               'ligplaats': None,
#               'mutatie_gebruiker': 'DBI',
#               'nummeraanduidingidentificatie': '0363200000077014',
#               'openbare_ruimte': {'_display': 'Damstraat',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}},
#                                   'dataset': 'bag',
#                                   'landelijk_id': '0363300000003189'},
#               'postcode': '1012JM',
#               'sleutelverzendend': '03630000077014',
#               'stadsdeel': {'_display': 'Centrum (A)',
#                             '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}},
#                             'code': 'A',
#                             'dataset': 'gebieden',
#                             'naam': 'Centrum'},
#               'standplaats': None,
#               'status': {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'},
#               'type': 'Verblijfsobject',
#               'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630011872323/',
#               'woonplaats': {'_display': 'Amsterdam',
#                              '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}},
#                              'dataset': 'bag',
#                              'landelijk_id': '3594'}},
#              {'_display': 'Damstraat 26-3',
#               '_geometrie': {'coordinates': [121478.0, 487246.0],
#                              'type': 'Point'},
#               '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077017/'}},
#               'adres': 'Damstraat 26-3',
#               'adres_nummer': '',
#               'begin_geldigheid': '1005-01-01',
#               'bouwblok': {'_display': 'YA27',
#                            '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099976/'}},
#                            'dataset': 'gebieden',
#                            'id': '03630012099976'},
#               'bron': None,
#               'buurt': {'_display': 'Nes e.o. (A00d)',
#                         '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/'}},
#                         'code': '00d',
#                         'dataset': 'gebieden',
#                         'naam': 'Nes e.o.'},
#               'buurtcombinatie': {'_display': 'Burgwallen-Oude Zijde (00)',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}},
#                                   'dataset': 'gebieden',
#                                   'naam': 'Burgwallen-Oude Zijde',
#                                   'vollcode': 'A00'},
#               'dataset': 'bag',
#               'date_modified': '2018-08-22T23:02:15.076629Z',
#               'document_mutatie': '1005-01-01',
#               'document_nummer': 'GV00000402',
#               'einde_geldigheid': None,
#               'gebiedsgerichtwerken': {'_display': 'Centrum-West (DX01)',
#                                        '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}},
#                                        'code': 'DX01',
#                                        'dataset': 'gebieden',
#                                        'naam': 'Centrum-West'},
#               'grootstedelijkgebied': None,
#               'hoofdadres': True,
#               'huisletter': '',
#               'huisnummer': 26,
#               'huisnummer_toevoeging': '3',
#               'ligplaats': None,
#               'mutatie_gebruiker': 'DBI',
#               'nummeraanduidingidentificatie': '0363200000077017',
#               'openbare_ruimte': {'_display': 'Damstraat',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}},
#                                   'dataset': 'bag',
#                                   'landelijk_id': '0363300000003189'},
#               'postcode': '1012JM',
#               'sleutelverzendend': '03630000077017',
#               'stadsdeel': {'_display': 'Centrum (A)',
#                             '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}},
#                             'code': 'A',
#                             'dataset': 'gebieden',
#                             'naam': 'Centrum'},
#               'standplaats': None,
#               'status': {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'},
#               'type': 'Verblijfsobject',
#               'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614808/',
#               'woonplaats': {'_display': 'Amsterdam',
#                              '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}},
#                              'dataset': 'bag',
#                              'landelijk_id': '3594'}},
#              {'_display': 'Damstraat 27',
#               '_geometrie': {'coordinates': [121515.0, 487246.0],
#                              'type': 'Point'},
#               '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077018/'}},
#               'adres': 'Damstraat 27',
#               'adres_nummer': '',
#               'begin_geldigheid': '1005-01-01',
#               'bouwblok': {'_display': 'YA22',
#                            '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/'}},
#                            'dataset': 'gebieden',
#                            'id': '03630012099548'},
#               'bron': None,
#               'buurt': {'_display': 'Oude Kerk e.o. (A00b)',
#                         '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/'}},
#                         'code': '00b',
#                         'dataset': 'gebieden',
#                         'naam': 'Oude Kerk e.o.'},
#               'buurtcombinatie': {'_display': 'Burgwallen-Oude Zijde (00)',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}},
#                                   'dataset': 'gebieden',
#                                   'naam': 'Burgwallen-Oude Zijde',
#                                   'vollcode': 'A00'},
#               'dataset': 'bag',
#               'date_modified': '2018-08-22T23:05:14.578694Z',
#               'document_mutatie': '1005-01-01',
#               'document_nummer': 'GV00000402',
#               'einde_geldigheid': None,
#               'gebiedsgerichtwerken': {'_display': 'Centrum-West (DX01)',
#                                        '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}},
#                                        'code': 'DX01',
#                                        'dataset': 'gebieden',
#                                        'naam': 'Centrum-West'},
#               'grootstedelijkgebied': None,
#               'hoofdadres': True,
#               'huisletter': '',
#               'huisnummer': 27,
#               'huisnummer_toevoeging': '',
#               'ligplaats': None,
#               'mutatie_gebruiker': 'DBI',
#               'nummeraanduidingidentificatie': '0363200000077018',
#               'openbare_ruimte': {'_display': 'Damstraat',
#                                   '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}},
#                                   'dataset': 'bag',
#                                   'landelijk_id': '0363300000003189'},
#               'postcode': '1012JL',
#               'sleutelverzendend': '03630000077018',
#               'stadsdeel': {'_display': 'Centrum (A)',
#                             '_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}},
#                             'code': 'A',
#                             'dataset': 'gebieden',
#                             'naam': 'Centrum'},
#               'standplaats': None,
#               'status': {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'},
#               'type': 'Verblijfsobject',
#               'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614809/',
#               'woonplaats': {'_display': 'Amsterdam',
#                              '_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}},
#                              'dataset': 'bag',
#                              'landelijk_id': '3594'}}]}

# %%
# Selecteer alleen het resultaat
output_data = query_address_details['results']
print (output_data)
# Out:
# [{'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076981/'}}, '_display': 'Damstraat 2-HL', 'sleutelverzendend': '03630000076981', 'nummeraanduidingidentificatie': '0363200000076981', 'date_modified': '2018-08-22T23:02:15.057854Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status': {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, 'bron': None, 'adres': 'Damstraat 2-HL', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HL', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte': {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614784/', 'buurt': {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/'}}, '_display': 'Nes e.o. (A00d)', 'code': '00d', 'naam': 'Nes e.o.', 'dataset': 'gebieden'}, 'buurtcombinatie': {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, 'gebiedsgerichtwerken': {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, 'grootstedelijkgebied': None, 'stadsdeel': {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, 'woonplaats': {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, 'bouwblok': {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/'}}, '_display': 'YA26', 'id': '03630012100692', 'dataset': 'gebieden'}, '_geometrie': {'type': 'Point', 'coordinates': [121421.0, 487278.0]}, 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076982/'}}, '_display': 'Damstraat 2-HR', 'sleutelverzendend': '03630000076982', 'nummeraanduidingidentificatie': '0363200000076982', 'date_modified': '2018-08-22T23:14:09.272367Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status': {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, 'bron': None, 'adres': 'Damstraat 2-HR', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HR', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte': {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614785/', 'buurt': {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/'}}, '_display': 'Nes e.o. (A00d)', 'code': '00d', 'naam': 'Nes e.o.', 'dataset': 'gebieden'}, 'buurtcombinatie': {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, 'gebiedsgerichtwerken': {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': ...

# %%
# Laad functie in om JSON antwoord als CSV op te slaan
import os, json, csv
def save_file(data, filename):
    full_path = filename # os.path.join(output_folder, filename)
    with open(full_path, 'w') as out_file:
        # get header titles based on first object in array
        header = list(data[0].keys())
        print(header)   
        csvWriter = csv.writer(out_file, delimiter=';', quoting=csv.QUOTE_MINIMAL)
        csvWriter.writerow(header)
        for row in data:
            csvWriter.writerow(row.values())
            print(row.values())
    print("File saved as: {}".format(full_path))

# %%
# Gebruik de functie om de data weg te schrijven als CSV
save_file(output_data, 'test.csv')
# Out:
# ['_links', '_display', 'sleutelverzendend', 'nummeraanduidingidentificatie', 'date_modified', 'document_mutatie', 'document_nummer', 'begin_geldigheid', 'einde_geldigheid', 'mutatie_gebruiker', 'status', 'bron', 'adres', 'postcode', 'huisnummer', 'huisletter', 'huisnummer_toevoeging', 'type', 'adres_nummer', 'openbare_ruimte', 'hoofdadres', 'ligplaats', 'standplaats', 'verblijfsobject', 'buurt', 'buurtcombinatie', 'gebiedsgerichtwerken', 'grootstedelijkgebied', 'stadsdeel', 'woonplaats', 'bouwblok', '_geometrie', 'dataset']
# dict_values([{'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076981/'}}, 'Damstraat 2-HL', '03630000076981', '0363200000076981', '2018-08-22T23:02:15.057854Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, None, 'Damstraat 2-HL', '1012JM', 2, '', 'HL', 'Verblijfsobject', '', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614784/', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/'}}, '_display': 'Nes e.o. (A00d)', 'code': '00d', 'naam': 'Nes e.o.', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, None, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/'}}, '_display': 'YA26', 'id': '03630012100692', 'dataset': 'gebieden'}, {'type': 'Point', 'coordinates': [121421.0, 487278.0]}, 'bag'])
# dict_values([{'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076982/'}}, 'Damstraat 2-HR', '03630000076982', '0363200000076982', '2018-08-22T23:14:09.272367Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, None, 'Damstraat 2-HR', '1012JM', 2, '', 'HR', 'Verblijfsobject', '', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614785/', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/'}}, '_display': 'Nes e.o. (A00d)', 'code': '00d', 'naam': 'Nes e.o.', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, None, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/'}}, '_display': 'YA26', 'id': '03630012100692', 'dataset': 'gebieden'}, {'type': 'Point', 'coordinates': [121421.0, 487278.0]}, 'bag'])
# dict_values([{'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076985/'}}, 'Damstraat 2A', '03630000076985', '0363200000076985', '2018-08-22T23:05:14.573148Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, None, 'Damstraat 2A', '1012JM', 2, 'A', '', 'Verblijfsobject', '', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614787/', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/'}}, '_display': 'Nes e.o. (A00d)', 'code': '00d', 'naam': 'Nes e.o.', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, None, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/'}}, '_display': 'YA26', 'id': '03630012100692', 'dataset': 'gebieden'}, {'type': 'Point', 'coordinates': [121423.0, 487276.0]}, 'bag'])
# dict_values([{'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076986/'}}, 'Damstraat 3', '03630000076986', '0363200000076986', '2018-08-22T23:02:15.063193Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, None, 'Damstraat 3', '1012JL', 3, '', '', 'Verblijfsobject', '', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614788/', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/'}}, '_display': 'Oude Kerk e.o. (A00b)', 'code': '00b', 'naam': 'Oude Kerk e.o.', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, None, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012095692/'}}, '_display': 'YA23', 'id': '03630012095692', 'dataset': 'gebieden'}, {'type': 'Point', 'coordinates': [121445.0, 487283.0]}, 'bag'])
# dict_values([{'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076987/'}}, 'Damstraat 4', '03630000076987', '0363200000076987', '2018-08-22T23:08:11.449480Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, None, 'Damstraat 4', '1012JM', 4, '', '', 'Verblijfsobject', '', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614789/', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/'}}, '_display': 'Nes e.o. (A00d)', 'code': '00d', 'naam': 'Nes e.o.', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, None, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/'}}, '_display': 'YA26', 'id': '03630012100692', 'dataset': 'gebieden'}, {'type': 'Point', 'coordinates': [121428.0, 487272.0]}, 'bag'])
# dict_values([{'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076988/'}}, 'Damstraat 5', '03630000076988', '0363200000076988', '2018-08-22T23:02:15.065902Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, None, 'Damstraat 5', '1012JL', 5, '', '', 'Verblijfsobject', '', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614790/', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/'}}, '_display': 'Oude Kerk e.o. (A00b)', 'code': '00b', 'naam': 'Oude Kerk e.o.', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, None, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012095692/'}}, '_display': 'YA23', 'id': '03630012095692', 'dataset': 'gebieden'}, {'type': 'Point', 'coordinates': [121454.0, 487278.0]}, 'bag'])
# dict_values([{'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076989/'}}, 'Damstraat 6', '03630000076989', '0363200000076989', '2018-08-22T23:02:15.068531Z', '2009-12-07', 'GV00000402', '2009-12-07', None, 'DBI', {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, None, 'Damstraat 6', '1012JM', 6, '', '', 'Verblijfsobject', '', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614791/', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/'}}, '_display': 'Nes e.o. (A00d)', 'code': '00d', 'naam': 'Nes e.o.', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, None, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/'}}, '_display': 'YA26', 'id': '03630012100692', 'dataset': 'gebieden'}, {'type': 'Point', 'coordinates': [121431.0, 487271.0]}, 'bag'])
# dict_values([{'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076990/'}}, 'Damstraat 7', '03630000076990', '0363200000076990', '2018-08-22T23:05:14.575977Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, None, 'Damstraat 7', '1012JL', 7, '', '', 'Verblijfsobject', '', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614792/', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/'}}, '_display': 'Oude Kerk e.o. (A00b)', 'code': '00b', 'naam': 'Oude Kerk e.o.', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, None, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012095692/'}}, '_display': 'YA23', 'id': '03630012095692', 'dataset': 'gebieden'}, {'type': 'Point', 'coordinates': [121463.0, 487274.0]}, 'bag'])
# dict_values([{'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076992/'}}, 'Damstraat 9', '03630000076992', '0363200000076992', '2018-08-22T23:08:11.452084Z', '1980-01-01', 'GV00000402', '1980-01-01', None, 'DBI', {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, None, 'Damstraat 9', '1012JL', 9, '', '', 'Verblijfsobject', '', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630001015263/', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/'}}, '_display': 'Oude Kerk e.o. (A00b)', 'code': '00b', 'naam': 'Oude Kerk e.o.', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, None, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/'}}, '_display': 'YA22', 'id': '03630012099548', 'dataset': 'gebieden'}, {'type': 'Point', 'coordinates': [121470.0, 487270.0]}, 'bag'])
# dict_values([{'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076994/'}}, 'Damstraat 11', '03630000076994', '0363200000076994', '2018-08-22T23:08:11.454847Z', '1980-01-01', 'GV00000402', '1980-01-01', None, 'DBI', {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, None, 'Damstraat 11', '1012JL', 11, '', '', 'Verblijfsobject', '', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630001015264/', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/'}}, '_display': 'Oude Kerk e.o. (A00b)', 'code': '00b', 'naam': 'Oude Kerk e.o.', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, None, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/'}}, '_display': 'YA22', 'id': '03630012099548', 'dataset': 'gebieden'}, {'type': 'Point', 'coordinates': [121475.0, 487267.0]}, 'bag'])
# dict_values([{'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076995/'}}, 'Damstraat 12', '03630000076995', '0363200000076995', '2018-08-22T23:17:06.864934Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, None, 'Damstraat 12', '1012JM', 12, '', '', 'Verblijfsobject', '', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614794/', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/'}}, '_display': 'Nes e.o. (A00d)', 'code': '00d', 'naam': 'Nes e.o.', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, None, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/'}}, '_display': 'YA26', 'id': '03630012100692', 'dataset': 'gebieden'}, {'type': 'Point', 'coordinates': [121442.0, 487267.0]}, 'bag'])
# dict_values([{'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076997/'}}, 'Damstraat 13', '03630000076997', '0363200000076997', '2018-08-22T22:56:03.067623Z', '1980-01-01', 'GV00000402', '1980-01-01', None, 'DBI', {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, None, 'Damstraat 13', '1012JL', 13, '', '', 'Verblijfsobject', '', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630001015265/', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/'}}, '_display': 'Oude Kerk e.o. (A00b)', 'code': '00b', 'naam': 'Oude Kerk e.o.', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, None, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/'}}, '_display': 'YA22', 'id': '03630012099548', 'dataset': 'gebieden'}, {'type': 'Point', 'coordinates': [121479.0, 487265.0]}, 'bag'])
# dict_values([{'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076999/'}}, 'Damstraat 15', '03630000076999', '0363200000076999', '2018-08-22T23:08:11.457705Z', '1980-01-01', 'GV00000402', '1980-01-01', None, 'DBI', {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, None, 'Damstraat 15', '1012JL', 15, '', '', 'Verblijfsobject', '', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630001015266/', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/'}}, '_display': 'Oude Kerk e.o. (A00b)', 'code': '00b', 'naam': 'Oude Kerk e.o.', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, None, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/'}}, '_display': 'YA22', 'id': '03630012099548', 'dataset': 'gebieden'}, {'type': 'Point', 'coordinates': [121486.0, 487260.0]}, 'bag'])
# dict_values([{'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077000/'}}, 'Damstraat 16-H', '03630000077000', '0363200000077000', '2018-08-22T23:11:10.391564Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, None, 'Damstraat 16-H', '1012JM', 16, '', 'H', 'Verblijfsobject', '', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614802/', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/'}}, '_display': 'Nes e.o. (A00d)', 'code': '00d', 'naam': 'Nes e.o.', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, None, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/'}}, '_display': 'YA26', 'id': '03630012100692', 'dataset': 'gebieden'}, {'type': 'Point', 'coordinates': [121451.0, 487261.0]}, 'bag'])
# dict_values([{'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077002/'}}, 'Damstraat 16-2', '03630000077002', '0363200000077002', '2018-08-22T23:08:11.460416Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, None, 'Damstraat 16-2', '1012JM', 16, '', '2', 'Verblijfsobject', '', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614803/', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/'}}, '_display': 'Nes e.o. (A00d)', 'code': '00d', 'naam': 'Nes e.o.', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, None, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/'}}, '_display': 'YA26', 'id': '03630012100692', 'dataset': 'gebieden'}, {'type': 'Point', 'coordinates': [121451.0, 487261.0]}, 'bag'])
# dict_values([{'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077003/'}}, 'Damstraat 16-3', '03630000077003', '0363200000077003', '2018-08-22T23:08:11.463138Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, None, 'Damstraat 16-3', '1012JM', 16, '', '3', 'Verblijfsobject', '', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614804/', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/'}}, '_display': 'Nes e.o. (A00d)', 'code': '00d', 'naam': 'Nes e.o.', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, None, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/'}}, '_display': 'YA26', 'id': '03630012100692', 'dataset': 'gebieden'}, {'type': 'Point', 'coordinates': [121451.0, 487261.0]}, 'bag'])
# dict_values([{'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077004/'}}, 'Damstraat 17', '03630000077004', '0363200000077004', '2018-08-22T23:17:06.867798Z', '1980-01-01', 'GV00000402', '1980-01-01', None, 'DBI', {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, None, 'Damstraat 17', '1012JL', 17, '', '', 'Verblijfsobject', '', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630001015267/', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/'}}, '_display': 'Oude Kerk e.o. (A00b)', 'code': '00b', 'naam': 'Oude Kerk e.o.', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, None, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/'}}, '_display': 'YA22', 'id': '03630012099548', 'dataset': 'gebieden'}, {'type': 'Point', 'coordinates': [121495.0, 487255.0]}, 'bag'])
# dict_values([{'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077007/'}}, 'Damstraat 19', '03630000077007', '0363200000077007', '2018-08-22T23:14:09.275295Z', '1980-01-01', 'GV00000402', '1980-01-01', None, 'DBI', {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, None, 'Damstraat 19', '1012JL', 19, '', '', 'Verblijfsobject', '', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630001015268/', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/'}}, '_display': 'Oude Kerk e.o. (A00b)', 'code': '00b', 'naam': 'Oude Kerk e.o.', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, None, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/'}}, '_display': 'YA22', 'id': '03630012099548', 'dataset': 'gebieden'}, {'type': 'Point', 'coordinates': [121499.0, 487254.0]}, 'bag'])
# dict_values([{'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077008/'}}, 'Damstraat 20', '03630000077008', '0363200000077008', '2018-08-22T23:14:09.277954Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, None, 'Damstraat 20', '1012JM', 20, '', '', 'Verblijfsobject', '', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614806/', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/'}}, '_display': 'Nes e.o. (A00d)', 'code': '00d', 'naam': 'Nes e.o.', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, None, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/'}}, '_display': 'YA26', 'id': '03630012100692', 'dataset': 'gebieden'}, {'type': 'Point', 'coordinates': [121459.0, 487257.0]}, 'bag'])
# dict_values([{'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077009/'}}, 'Damstraat 21', '03630000077009', '0363200000077009', '2018-08-22T23:08:11.465954Z', '1980-01-01', 'GV00000402', '1980-01-01', None, 'DBI', {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, None, 'Damstraat 21', '1012JL', 21, '', '', 'Verblijfsobject', '', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630001015269/', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/'}}, '_display': 'Oude Kerk e.o. (A00b)', 'code': '00b', 'naam': 'Oude Kerk e.o.', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, None, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/'}}, '_display': 'YA22', 'id': '03630012099548', 'dataset': 'gebieden'}, {'type': 'Point', 'coordinates': [121504.0, 487251.0]}, 'bag'])
# dict_values([{'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077011/'}}, 'Damstraat 23', '03630000077011', '0363200000077011', '2018-08-22T23:02:15.071158Z', '1980-01-01', 'GV00000402', '1980-01-01', None, 'DBI', {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, None, 'Damstraat 23', '1012JL', 23, '', '', 'Verblijfsobject', '', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630001015270/', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/'}}, '_display': 'Oude Kerk e.o. (A00b)', 'code': '00b', 'naam': 'Oude Kerk e.o.', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, None, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/'}}, '_display': 'YA22', 'id': '03630012099548', 'dataset': 'gebieden'}, {'type': 'Point', 'coordinates': [121507.0, 487250.0]}, 'bag'])
# dict_values([{'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077013/'}}, 'Damstraat 25', '03630000077013', '0363200000077013', '2018-08-22T23:02:15.073726Z', '1980-01-01', 'GV00000402', '1980-01-01', None, 'DBI', {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, None, 'Damstraat 25', '1012JL', 25, '', '', 'Verblijfsobject', '', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630001015271/', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/'}}, '_display': 'Oude Kerk e.o. (A00b)', 'code': '00b', 'naam': 'Oude Kerk e.o.', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, None, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/'}}, '_display': 'YA22', 'id': '03630012099548', 'dataset': 'gebieden'}, {'type': 'Point', 'coordinates': [121511.0, 487248.0]}, 'bag'])
# dict_values([{'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077014/'}}, 'Damstraat 26-H', '03630000077014', '0363200000077014', '2018-08-22T22:58:22.714234Z', '2014-03-15', 'SA00003980_RB02OR', '2014-03-15', None, 'DBI', {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, None, 'Damstraat 26-H', '1012JM', 26, '', 'H', 'Verblijfsobject', '', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630011872323/', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/'}}, '_display': 'Nes e.o. (A00d)', 'code': '00d', 'naam': 'Nes e.o.', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, None, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099976/'}}, '_display': 'YA27', 'id': '03630012099976', 'dataset': 'gebieden'}, {'type': 'Point', 'coordinates': [121478.0, 487246.0]}, 'bag'])
# dict_values([{'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077017/'}}, 'Damstraat 26-3', '03630000077017', '0363200000077017', '2018-08-22T23:02:15.076629Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, None, 'Damstraat 26-3', '1012JM', 26, '', '3', 'Verblijfsobject', '', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614808/', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/'}}, '_display': 'Nes e.o. (A00d)', 'code': '00d', 'naam': 'Nes e.o.', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, None, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099976/'}}, '_display': 'YA27', 'id': '03630012099976', 'dataset': 'gebieden'}, {'type': 'Point', 'coordinates': [121478.0, 487246.0]}, 'bag'])
# dict_values([{'self': {'href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077018/'}}, 'Damstraat 27', '03630000077018', '0363200000077018', '2018-08-22T23:05:14.578694Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', {'code': '16', 'omschrijving': 'Naamgeving uitgegeven'}, None, 'Damstraat 27', '1012JL', 27, '', '', 'Verblijfsobject', '', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/'}}, '_display': 'Damstraat', 'landelijk_id': '0363300000003189', 'dataset': 'bag'}, True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614809/', {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/'}}, '_display': 'Oude Kerk e.o. (A00b)', 'code': '00b', 'naam': 'Oude Kerk e.o.', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/'}}, '_display': 'Burgwallen-Oude Zijde (00)', 'naam': 'Burgwallen-Oude Zijde', 'vollcode': 'A00', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/'}}, '_display': 'Centrum-West (DX01)', 'code': 'DX01', 'naam': 'Centrum-West', 'dataset': 'gebieden'}, None, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/'}}, '_display': 'Centrum (A)', 'code': 'A', 'naam': 'Centrum', 'dataset': 'gebieden'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/'}}, '_display': 'Amsterdam', 'landelijk_id': '3594', 'dataset': 'bag'}, {'_links': {'self': {'href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/'}}, '_display': 'YA22', 'id': '03630012099548', 'dataset': 'gebieden'}, {'type': 'Point', 'coordinates': [121515.0, 487246.0]}, 'bag'])
# File saved as: test.csv

# %%
# Sla de geneste json objecten plat met deze functie
# https://github.com/Amsterdam/data-processing/blob/master/src/datapunt_processing/helpers/json_dict_handlers.py
def flatten_json(json_object):
    """
    Flatten nested json Object.
    Args:
        1 json_object, for example: {"key": "subkey": { "subsubkey":"value" }}
    Returns:
        {"key.subkey.subsubkey":"value"}
    Source:
        https://towardsdatascience.com/flattening-json-objects-in-python-f5343c794b10
    """
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '.')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '.')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(json_object)
    return out

# %%
output_data_flat = []
for item in output_data:
    item= flatten_json(item)
    output_data_flat.append(item)
    print(output_data_flat)
# Out:
# [{'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076981/', '_display': 'Damstraat 2-HL', 'sleutelverzendend': '03630000076981', 'nummeraanduidingidentificatie': '0363200000076981', 'date_modified': '2018-08-22T23:02:15.057854Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HL', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HL', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614784/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtcombinatie.naam': 'Burgwallen-Oude Zijde', 'buurtcombinatie.vollcode': 'A00', 'buurtcombinatie.dataset': 'gebieden', 'gebiedsgerichtwerken._links.self.href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'gebiedsgerichtwerken._display': 'Centrum-West (DX01)', 'gebiedsgerichtwerken.code': 'DX01', 'gebiedsgerichtwerken.naam': 'Centrum-West', 'gebiedsgerichtwerken.dataset': 'gebieden', 'grootstedelijkgebied': None, 'stadsdeel._links.self.href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'stadsdeel._display': 'Centrum (A)', 'stadsdeel.code': 'A', 'stadsdeel.naam': 'Centrum', 'stadsdeel.dataset': 'gebieden', 'woonplaats._links.self.href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'woonplaats._display': 'Amsterdam', 'woonplaats.landelijk_id': '3594', 'woonplaats.dataset': 'bag', 'bouwblok._links.self.href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/', 'bouwblok._display': 'YA26', 'bouwblok.id': '03630012100692', 'bouwblok.dataset': 'gebieden', '_geometrie.type': 'Point', '_geometrie.coordinates.0': 121421.0, '_geometrie.coordinates.1': 487278.0, 'dataset': 'bag'}]
# [{'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076981/', '_display': 'Damstraat 2-HL', 'sleutelverzendend': '03630000076981', 'nummeraanduidingidentificatie': '0363200000076981', 'date_modified': '2018-08-22T23:02:15.057854Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HL', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HL', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614784/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtcombinatie.naam': 'Burgwallen-Oude Zijde', 'buurtcombinatie.vollcode': 'A00', 'buurtcombinatie.dataset': 'gebieden', 'gebiedsgerichtwerken._links.self.href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'gebiedsgerichtwerken._display': 'Centrum-West (DX01)', 'gebiedsgerichtwerken.code': 'DX01', 'gebiedsgerichtwerken.naam': 'Centrum-West', 'gebiedsgerichtwerken.dataset': 'gebieden', 'grootstedelijkgebied': None, 'stadsdeel._links.self.href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'stadsdeel._display': 'Centrum (A)', 'stadsdeel.code': 'A', 'stadsdeel.naam': 'Centrum', 'stadsdeel.dataset': 'gebieden', 'woonplaats._links.self.href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'woonplaats._display': 'Amsterdam', 'woonplaats.landelijk_id': '3594', 'woonplaats.dataset': 'bag', 'bouwblok._links.self.href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/', 'bouwblok._display': 'YA26', 'bouwblok.id': '03630012100692', 'bouwblok.dataset': 'gebieden', '_geometrie.type': 'Point', '_geometrie.coordinates.0': 121421.0, '_geometrie.coordinates.1': 487278.0, 'dataset': 'bag'}, {'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076982/', '_display': 'Damstraat 2-HR', 'sleutelverzendend': '03630000076982', 'nummeraanduidingidentificatie': '0363200000076982', 'date_modified': '2018-08-22T23:14:09.272367Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HR', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HR', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614785/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtco ...
# [{'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076981/', '_display': 'Damstraat 2-HL', 'sleutelverzendend': '03630000076981', 'nummeraanduidingidentificatie': '0363200000076981', 'date_modified': '2018-08-22T23:02:15.057854Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HL', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HL', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614784/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtcombinatie.naam': 'Burgwallen-Oude Zijde', 'buurtcombinatie.vollcode': 'A00', 'buurtcombinatie.dataset': 'gebieden', 'gebiedsgerichtwerken._links.self.href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'gebiedsgerichtwerken._display': 'Centrum-West (DX01)', 'gebiedsgerichtwerken.code': 'DX01', 'gebiedsgerichtwerken.naam': 'Centrum-West', 'gebiedsgerichtwerken.dataset': 'gebieden', 'grootstedelijkgebied': None, 'stadsdeel._links.self.href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'stadsdeel._display': 'Centrum (A)', 'stadsdeel.code': 'A', 'stadsdeel.naam': 'Centrum', 'stadsdeel.dataset': 'gebieden', 'woonplaats._links.self.href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'woonplaats._display': 'Amsterdam', 'woonplaats.landelijk_id': '3594', 'woonplaats.dataset': 'bag', 'bouwblok._links.self.href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/', 'bouwblok._display': 'YA26', 'bouwblok.id': '03630012100692', 'bouwblok.dataset': 'gebieden', '_geometrie.type': 'Point', '_geometrie.coordinates.0': 121421.0, '_geometrie.coordinates.1': 487278.0, 'dataset': 'bag'}, {'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076982/', '_display': 'Damstraat 2-HR', 'sleutelverzendend': '03630000076982', 'nummeraanduidingidentificatie': '0363200000076982', 'date_modified': '2018-08-22T23:14:09.272367Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HR', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HR', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614785/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtco ...
# [{'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076981/', '_display': 'Damstraat 2-HL', 'sleutelverzendend': '03630000076981', 'nummeraanduidingidentificatie': '0363200000076981', 'date_modified': '2018-08-22T23:02:15.057854Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HL', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HL', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614784/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtcombinatie.naam': 'Burgwallen-Oude Zijde', 'buurtcombinatie.vollcode': 'A00', 'buurtcombinatie.dataset': 'gebieden', 'gebiedsgerichtwerken._links.self.href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'gebiedsgerichtwerken._display': 'Centrum-West (DX01)', 'gebiedsgerichtwerken.code': 'DX01', 'gebiedsgerichtwerken.naam': 'Centrum-West', 'gebiedsgerichtwerken.dataset': 'gebieden', 'grootstedelijkgebied': None, 'stadsdeel._links.self.href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'stadsdeel._display': 'Centrum (A)', 'stadsdeel.code': 'A', 'stadsdeel.naam': 'Centrum', 'stadsdeel.dataset': 'gebieden', 'woonplaats._links.self.href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'woonplaats._display': 'Amsterdam', 'woonplaats.landelijk_id': '3594', 'woonplaats.dataset': 'bag', 'bouwblok._links.self.href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/', 'bouwblok._display': 'YA26', 'bouwblok.id': '03630012100692', 'bouwblok.dataset': 'gebieden', '_geometrie.type': 'Point', '_geometrie.coordinates.0': 121421.0, '_geometrie.coordinates.1': 487278.0, 'dataset': 'bag'}, {'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076982/', '_display': 'Damstraat 2-HR', 'sleutelverzendend': '03630000076982', 'nummeraanduidingidentificatie': '0363200000076982', 'date_modified': '2018-08-22T23:14:09.272367Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HR', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HR', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614785/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtco ...
# [{'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076981/', '_display': 'Damstraat 2-HL', 'sleutelverzendend': '03630000076981', 'nummeraanduidingidentificatie': '0363200000076981', 'date_modified': '2018-08-22T23:02:15.057854Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HL', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HL', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614784/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtcombinatie.naam': 'Burgwallen-Oude Zijde', 'buurtcombinatie.vollcode': 'A00', 'buurtcombinatie.dataset': 'gebieden', 'gebiedsgerichtwerken._links.self.href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'gebiedsgerichtwerken._display': 'Centrum-West (DX01)', 'gebiedsgerichtwerken.code': 'DX01', 'gebiedsgerichtwerken.naam': 'Centrum-West', 'gebiedsgerichtwerken.dataset': 'gebieden', 'grootstedelijkgebied': None, 'stadsdeel._links.self.href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'stadsdeel._display': 'Centrum (A)', 'stadsdeel.code': 'A', 'stadsdeel.naam': 'Centrum', 'stadsdeel.dataset': 'gebieden', 'woonplaats._links.self.href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'woonplaats._display': 'Amsterdam', 'woonplaats.landelijk_id': '3594', 'woonplaats.dataset': 'bag', 'bouwblok._links.self.href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/', 'bouwblok._display': 'YA26', 'bouwblok.id': '03630012100692', 'bouwblok.dataset': 'gebieden', '_geometrie.type': 'Point', '_geometrie.coordinates.0': 121421.0, '_geometrie.coordinates.1': 487278.0, 'dataset': 'bag'}, {'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076982/', '_display': 'Damstraat 2-HR', 'sleutelverzendend': '03630000076982', 'nummeraanduidingidentificatie': '0363200000076982', 'date_modified': '2018-08-22T23:14:09.272367Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HR', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HR', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614785/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtco ...
# [{'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076981/', '_display': 'Damstraat 2-HL', 'sleutelverzendend': '03630000076981', 'nummeraanduidingidentificatie': '0363200000076981', 'date_modified': '2018-08-22T23:02:15.057854Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HL', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HL', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614784/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtcombinatie.naam': 'Burgwallen-Oude Zijde', 'buurtcombinatie.vollcode': 'A00', 'buurtcombinatie.dataset': 'gebieden', 'gebiedsgerichtwerken._links.self.href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'gebiedsgerichtwerken._display': 'Centrum-West (DX01)', 'gebiedsgerichtwerken.code': 'DX01', 'gebiedsgerichtwerken.naam': 'Centrum-West', 'gebiedsgerichtwerken.dataset': 'gebieden', 'grootstedelijkgebied': None, 'stadsdeel._links.self.href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'stadsdeel._display': 'Centrum (A)', 'stadsdeel.code': 'A', 'stadsdeel.naam': 'Centrum', 'stadsdeel.dataset': 'gebieden', 'woonplaats._links.self.href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'woonplaats._display': 'Amsterdam', 'woonplaats.landelijk_id': '3594', 'woonplaats.dataset': 'bag', 'bouwblok._links.self.href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/', 'bouwblok._display': 'YA26', 'bouwblok.id': '03630012100692', 'bouwblok.dataset': 'gebieden', '_geometrie.type': 'Point', '_geometrie.coordinates.0': 121421.0, '_geometrie.coordinates.1': 487278.0, 'dataset': 'bag'}, {'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076982/', '_display': 'Damstraat 2-HR', 'sleutelverzendend': '03630000076982', 'nummeraanduidingidentificatie': '0363200000076982', 'date_modified': '2018-08-22T23:14:09.272367Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HR', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HR', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614785/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtco ...
# [{'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076981/', '_display': 'Damstraat 2-HL', 'sleutelverzendend': '03630000076981', 'nummeraanduidingidentificatie': '0363200000076981', 'date_modified': '2018-08-22T23:02:15.057854Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HL', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HL', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614784/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtcombinatie.naam': 'Burgwallen-Oude Zijde', 'buurtcombinatie.vollcode': 'A00', 'buurtcombinatie.dataset': 'gebieden', 'gebiedsgerichtwerken._links.self.href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'gebiedsgerichtwerken._display': 'Centrum-West (DX01)', 'gebiedsgerichtwerken.code': 'DX01', 'gebiedsgerichtwerken.naam': 'Centrum-West', 'gebiedsgerichtwerken.dataset': 'gebieden', 'grootstedelijkgebied': None, 'stadsdeel._links.self.href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'stadsdeel._display': 'Centrum (A)', 'stadsdeel.code': 'A', 'stadsdeel.naam': 'Centrum', 'stadsdeel.dataset': 'gebieden', 'woonplaats._links.self.href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'woonplaats._display': 'Amsterdam', 'woonplaats.landelijk_id': '3594', 'woonplaats.dataset': 'bag', 'bouwblok._links.self.href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/', 'bouwblok._display': 'YA26', 'bouwblok.id': '03630012100692', 'bouwblok.dataset': 'gebieden', '_geometrie.type': 'Point', '_geometrie.coordinates.0': 121421.0, '_geometrie.coordinates.1': 487278.0, 'dataset': 'bag'}, {'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076982/', '_display': 'Damstraat 2-HR', 'sleutelverzendend': '03630000076982', 'nummeraanduidingidentificatie': '0363200000076982', 'date_modified': '2018-08-22T23:14:09.272367Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HR', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HR', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614785/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtco ...
# [{'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076981/', '_display': 'Damstraat 2-HL', 'sleutelverzendend': '03630000076981', 'nummeraanduidingidentificatie': '0363200000076981', 'date_modified': '2018-08-22T23:02:15.057854Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HL', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HL', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614784/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtcombinatie.naam': 'Burgwallen-Oude Zijde', 'buurtcombinatie.vollcode': 'A00', 'buurtcombinatie.dataset': 'gebieden', 'gebiedsgerichtwerken._links.self.href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'gebiedsgerichtwerken._display': 'Centrum-West (DX01)', 'gebiedsgerichtwerken.code': 'DX01', 'gebiedsgerichtwerken.naam': 'Centrum-West', 'gebiedsgerichtwerken.dataset': 'gebieden', 'grootstedelijkgebied': None, 'stadsdeel._links.self.href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'stadsdeel._display': 'Centrum (A)', 'stadsdeel.code': 'A', 'stadsdeel.naam': 'Centrum', 'stadsdeel.dataset': 'gebieden', 'woonplaats._links.self.href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'woonplaats._display': 'Amsterdam', 'woonplaats.landelijk_id': '3594', 'woonplaats.dataset': 'bag', 'bouwblok._links.self.href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/', 'bouwblok._display': 'YA26', 'bouwblok.id': '03630012100692', 'bouwblok.dataset': 'gebieden', '_geometrie.type': 'Point', '_geometrie.coordinates.0': 121421.0, '_geometrie.coordinates.1': 487278.0, 'dataset': 'bag'}, {'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076982/', '_display': 'Damstraat 2-HR', 'sleutelverzendend': '03630000076982', 'nummeraanduidingidentificatie': '0363200000076982', 'date_modified': '2018-08-22T23:14:09.272367Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HR', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HR', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614785/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtco ...
# [{'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076981/', '_display': 'Damstraat 2-HL', 'sleutelverzendend': '03630000076981', 'nummeraanduidingidentificatie': '0363200000076981', 'date_modified': '2018-08-22T23:02:15.057854Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HL', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HL', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614784/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtcombinatie.naam': 'Burgwallen-Oude Zijde', 'buurtcombinatie.vollcode': 'A00', 'buurtcombinatie.dataset': 'gebieden', 'gebiedsgerichtwerken._links.self.href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'gebiedsgerichtwerken._display': 'Centrum-West (DX01)', 'gebiedsgerichtwerken.code': 'DX01', 'gebiedsgerichtwerken.naam': 'Centrum-West', 'gebiedsgerichtwerken.dataset': 'gebieden', 'grootstedelijkgebied': None, 'stadsdeel._links.self.href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'stadsdeel._display': 'Centrum (A)', 'stadsdeel.code': 'A', 'stadsdeel.naam': 'Centrum', 'stadsdeel.dataset': 'gebieden', 'woonplaats._links.self.href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'woonplaats._display': 'Amsterdam', 'woonplaats.landelijk_id': '3594', 'woonplaats.dataset': 'bag', 'bouwblok._links.self.href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/', 'bouwblok._display': 'YA26', 'bouwblok.id': '03630012100692', 'bouwblok.dataset': 'gebieden', '_geometrie.type': 'Point', '_geometrie.coordinates.0': 121421.0, '_geometrie.coordinates.1': 487278.0, 'dataset': 'bag'}, {'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076982/', '_display': 'Damstraat 2-HR', 'sleutelverzendend': '03630000076982', 'nummeraanduidingidentificatie': '0363200000076982', 'date_modified': '2018-08-22T23:14:09.272367Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HR', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HR', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614785/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtco ...
# [{'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076981/', '_display': 'Damstraat 2-HL', 'sleutelverzendend': '03630000076981', 'nummeraanduidingidentificatie': '0363200000076981', 'date_modified': '2018-08-22T23:02:15.057854Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HL', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HL', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614784/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtcombinatie.naam': 'Burgwallen-Oude Zijde', 'buurtcombinatie.vollcode': 'A00', 'buurtcombinatie.dataset': 'gebieden', 'gebiedsgerichtwerken._links.self.href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'gebiedsgerichtwerken._display': 'Centrum-West (DX01)', 'gebiedsgerichtwerken.code': 'DX01', 'gebiedsgerichtwerken.naam': 'Centrum-West', 'gebiedsgerichtwerken.dataset': 'gebieden', 'grootstedelijkgebied': None, 'stadsdeel._links.self.href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'stadsdeel._display': 'Centrum (A)', 'stadsdeel.code': 'A', 'stadsdeel.naam': 'Centrum', 'stadsdeel.dataset': 'gebieden', 'woonplaats._links.self.href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'woonplaats._display': 'Amsterdam', 'woonplaats.landelijk_id': '3594', 'woonplaats.dataset': 'bag', 'bouwblok._links.self.href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/', 'bouwblok._display': 'YA26', 'bouwblok.id': '03630012100692', 'bouwblok.dataset': 'gebieden', '_geometrie.type': 'Point', '_geometrie.coordinates.0': 121421.0, '_geometrie.coordinates.1': 487278.0, 'dataset': 'bag'}, {'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076982/', '_display': 'Damstraat 2-HR', 'sleutelverzendend': '03630000076982', 'nummeraanduidingidentificatie': '0363200000076982', 'date_modified': '2018-08-22T23:14:09.272367Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HR', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HR', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614785/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtco ...
# [{'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076981/', '_display': 'Damstraat 2-HL', 'sleutelverzendend': '03630000076981', 'nummeraanduidingidentificatie': '0363200000076981', 'date_modified': '2018-08-22T23:02:15.057854Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HL', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HL', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614784/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtcombinatie.naam': 'Burgwallen-Oude Zijde', 'buurtcombinatie.vollcode': 'A00', 'buurtcombinatie.dataset': 'gebieden', 'gebiedsgerichtwerken._links.self.href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'gebiedsgerichtwerken._display': 'Centrum-West (DX01)', 'gebiedsgerichtwerken.code': 'DX01', 'gebiedsgerichtwerken.naam': 'Centrum-West', 'gebiedsgerichtwerken.dataset': 'gebieden', 'grootstedelijkgebied': None, 'stadsdeel._links.self.href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'stadsdeel._display': 'Centrum (A)', 'stadsdeel.code': 'A', 'stadsdeel.naam': 'Centrum', 'stadsdeel.dataset': 'gebieden', 'woonplaats._links.self.href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'woonplaats._display': 'Amsterdam', 'woonplaats.landelijk_id': '3594', 'woonplaats.dataset': 'bag', 'bouwblok._links.self.href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/', 'bouwblok._display': 'YA26', 'bouwblok.id': '03630012100692', 'bouwblok.dataset': 'gebieden', '_geometrie.type': 'Point', '_geometrie.coordinates.0': 121421.0, '_geometrie.coordinates.1': 487278.0, 'dataset': 'bag'}, {'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076982/', '_display': 'Damstraat 2-HR', 'sleutelverzendend': '03630000076982', 'nummeraanduidingidentificatie': '0363200000076982', 'date_modified': '2018-08-22T23:14:09.272367Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HR', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HR', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614785/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtco ...
# [{'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076981/', '_display': 'Damstraat 2-HL', 'sleutelverzendend': '03630000076981', 'nummeraanduidingidentificatie': '0363200000076981', 'date_modified': '2018-08-22T23:02:15.057854Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HL', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HL', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614784/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtcombinatie.naam': 'Burgwallen-Oude Zijde', 'buurtcombinatie.vollcode': 'A00', 'buurtcombinatie.dataset': 'gebieden', 'gebiedsgerichtwerken._links.self.href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'gebiedsgerichtwerken._display': 'Centrum-West (DX01)', 'gebiedsgerichtwerken.code': 'DX01', 'gebiedsgerichtwerken.naam': 'Centrum-West', 'gebiedsgerichtwerken.dataset': 'gebieden', 'grootstedelijkgebied': None, 'stadsdeel._links.self.href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'stadsdeel._display': 'Centrum (A)', 'stadsdeel.code': 'A', 'stadsdeel.naam': 'Centrum', 'stadsdeel.dataset': 'gebieden', 'woonplaats._links.self.href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'woonplaats._display': 'Amsterdam', 'woonplaats.landelijk_id': '3594', 'woonplaats.dataset': 'bag', 'bouwblok._links.self.href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/', 'bouwblok._display': 'YA26', 'bouwblok.id': '03630012100692', 'bouwblok.dataset': 'gebieden', '_geometrie.type': 'Point', '_geometrie.coordinates.0': 121421.0, '_geometrie.coordinates.1': 487278.0, 'dataset': 'bag'}, {'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076982/', '_display': 'Damstraat 2-HR', 'sleutelverzendend': '03630000076982', 'nummeraanduidingidentificatie': '0363200000076982', 'date_modified': '2018-08-22T23:14:09.272367Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HR', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HR', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614785/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtco ...
# ...
# [{'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076981/', '_display': 'Damstraat 2-HL', 'sleutelverzendend': '03630000076981', 'nummeraanduidingidentificatie': '0363200000076981', 'date_modified': '2018-08-22T23:02:15.057854Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HL', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HL', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614784/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtcombinatie.naam': 'Burgwallen-Oude Zijde', 'buurtcombinatie.vollcode': 'A00', 'buurtcombinatie.dataset': 'gebieden', 'gebiedsgerichtwerken._links.self.href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'gebiedsgerichtwerken._display': 'Centrum-West (DX01)', 'gebiedsgerichtwerken.code': 'DX01', 'gebiedsgerichtwerken.naam': 'Centrum-West', 'gebiedsgerichtwerken.dataset': 'gebieden', 'grootstedelijkgebied': None, 'stadsdeel._links.self.href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'stadsdeel._display': 'Centrum (A)', 'stadsdeel.code': 'A', 'stadsdeel.naam': 'Centrum', 'stadsdeel.dataset': 'gebieden', 'woonplaats._links.self.href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'woonplaats._display': 'Amsterdam', 'woonplaats.landelijk_id': '3594', 'woonplaats.dataset': 'bag', 'bouwblok._links.self.href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/', 'bouwblok._display': 'YA26', 'bouwblok.id': '03630012100692', 'bouwblok.dataset': 'gebieden', '_geometrie.type': 'Point', '_geometrie.coordinates.0': 121421.0, '_geometrie.coordinates.1': 487278.0, 'dataset': 'bag'}, {'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076982/', '_display': 'Damstraat 2-HR', 'sleutelverzendend': '03630000076982', 'nummeraanduidingidentificatie': '0363200000076982', 'date_modified': '2018-08-22T23:14:09.272367Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HR', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HR', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614785/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtco ...
# [{'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076981/', '_display': 'Damstraat 2-HL', 'sleutelverzendend': '03630000076981', 'nummeraanduidingidentificatie': '0363200000076981', 'date_modified': '2018-08-22T23:02:15.057854Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HL', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HL', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614784/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtcombinatie.naam': 'Burgwallen-Oude Zijde', 'buurtcombinatie.vollcode': 'A00', 'buurtcombinatie.dataset': 'gebieden', 'gebiedsgerichtwerken._links.self.href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'gebiedsgerichtwerken._display': 'Centrum-West (DX01)', 'gebiedsgerichtwerken.code': 'DX01', 'gebiedsgerichtwerken.naam': 'Centrum-West', 'gebiedsgerichtwerken.dataset': 'gebieden', 'grootstedelijkgebied': None, 'stadsdeel._links.self.href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'stadsdeel._display': 'Centrum (A)', 'stadsdeel.code': 'A', 'stadsdeel.naam': 'Centrum', 'stadsdeel.dataset': 'gebieden', 'woonplaats._links.self.href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'woonplaats._display': 'Amsterdam', 'woonplaats.landelijk_id': '3594', 'woonplaats.dataset': 'bag', 'bouwblok._links.self.href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/', 'bouwblok._display': 'YA26', 'bouwblok.id': '03630012100692', 'bouwblok.dataset': 'gebieden', '_geometrie.type': 'Point', '_geometrie.coordinates.0': 121421.0, '_geometrie.coordinates.1': 487278.0, 'dataset': 'bag'}, {'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076982/', '_display': 'Damstraat 2-HR', 'sleutelverzendend': '03630000076982', 'nummeraanduidingidentificatie': '0363200000076982', 'date_modified': '2018-08-22T23:14:09.272367Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HR', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HR', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614785/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtco ...
# [{'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076981/', '_display': 'Damstraat 2-HL', 'sleutelverzendend': '03630000076981', 'nummeraanduidingidentificatie': '0363200000076981', 'date_modified': '2018-08-22T23:02:15.057854Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HL', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HL', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614784/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtcombinatie.naam': 'Burgwallen-Oude Zijde', 'buurtcombinatie.vollcode': 'A00', 'buurtcombinatie.dataset': 'gebieden', 'gebiedsgerichtwerken._links.self.href': 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'gebiedsgerichtwerken._display': 'Centrum-West (DX01)', 'gebiedsgerichtwerken.code': 'DX01', 'gebiedsgerichtwerken.naam': 'Centrum-West', 'gebiedsgerichtwerken.dataset': 'gebieden', 'grootstedelijkgebied': None, 'stadsdeel._links.self.href': 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'stadsdeel._display': 'Centrum (A)', 'stadsdeel.code': 'A', 'stadsdeel.naam': 'Centrum', 'stadsdeel.dataset': 'gebieden', 'woonplaats._links.self.href': 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'woonplaats._display': 'Amsterdam', 'woonplaats.landelijk_id': '3594', 'woonplaats.dataset': 'bag', 'bouwblok._links.self.href': 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/', 'bouwblok._display': 'YA26', 'bouwblok.id': '03630012100692', 'bouwblok.dataset': 'gebieden', '_geometrie.type': 'Point', '_geometrie.coordinates.0': 121421.0, '_geometrie.coordinates.1': 487278.0, 'dataset': 'bag'}, {'_links.self.href': 'https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076982/', '_display': 'Damstraat 2-HR', 'sleutelverzendend': '03630000076982', 'nummeraanduidingidentificatie': '0363200000076982', 'date_modified': '2018-08-22T23:14:09.272367Z', 'document_mutatie': '1005-01-01', 'document_nummer': 'GV00000402', 'begin_geldigheid': '1005-01-01', 'einde_geldigheid': None, 'mutatie_gebruiker': 'DBI', 'status.code': '16', 'status.omschrijving': 'Naamgeving uitgegeven', 'bron': None, 'adres': 'Damstraat 2-HR', 'postcode': '1012JM', 'huisnummer': 2, 'huisletter': '', 'huisnummer_toevoeging': 'HR', 'type': 'Verblijfsobject', 'adres_nummer': '', 'openbare_ruimte._links.self.href': 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'openbare_ruimte._display': 'Damstraat', 'openbare_ruimte.landelijk_id': '0363300000003189', 'openbare_ruimte.dataset': 'bag', 'hoofdadres': True, 'ligplaats': None, 'standplaats': None, 'verblijfsobject': 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614785/', 'buurt._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'buurt._display': 'Nes e.o. (A00d)', 'buurt.code': '00d', 'buurt.naam': 'Nes e.o.', 'buurt.dataset': 'gebieden', 'buurtcombinatie._links.self.href': 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'buurtcombinatie._display': 'Burgwallen-Oude Zijde (00)', 'buurtco ...

# %%
# Gebruik de functie om de data weg te schrijven als CSV
save_file(output_data_flat, 'test_flat.csv')
# Out:
# ['_links.self.href', '_display', 'sleutelverzendend', 'nummeraanduidingidentificatie', 'date_modified', 'document_mutatie', 'document_nummer', 'begin_geldigheid', 'einde_geldigheid', 'mutatie_gebruiker', 'status.code', 'status.omschrijving', 'bron', 'adres', 'postcode', 'huisnummer', 'huisletter', 'huisnummer_toevoeging', 'type', 'adres_nummer', 'openbare_ruimte._links.self.href', 'openbare_ruimte._display', 'openbare_ruimte.landelijk_id', 'openbare_ruimte.dataset', 'hoofdadres', 'ligplaats', 'standplaats', 'verblijfsobject', 'buurt._links.self.href', 'buurt._display', 'buurt.code', 'buurt.naam', 'buurt.dataset', 'buurtcombinatie._links.self.href', 'buurtcombinatie._display', 'buurtcombinatie.naam', 'buurtcombinatie.vollcode', 'buurtcombinatie.dataset', 'gebiedsgerichtwerken._links.self.href', 'gebiedsgerichtwerken._display', 'gebiedsgerichtwerken.code', 'gebiedsgerichtwerken.naam', 'gebiedsgerichtwerken.dataset', 'grootstedelijkgebied', 'stadsdeel._links.self.href', 'stadsdeel._display', 'stadsdeel.code', 'stadsdeel.naam', 'stadsdeel.dataset', 'woonplaats._links.self.href', 'woonplaats._display', 'woonplaats.landelijk_id', 'woonplaats.dataset', 'bouwblok._links.self.href', 'bouwblok._display', 'bouwblok.id', 'bouwblok.dataset', '_geometrie.type', '_geometrie.coordinates.0', '_geometrie.coordinates.1', 'dataset']
# dict_values(['https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076981/', 'Damstraat 2-HL', '03630000076981', '0363200000076981', '2018-08-22T23:02:15.057854Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', '16', 'Naamgeving uitgegeven', None, 'Damstraat 2-HL', '1012JM', 2, '', 'HL', 'Verblijfsobject', '', 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'Damstraat', '0363300000003189', 'bag', True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614784/', 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'Nes e.o. (A00d)', '00d', 'Nes e.o.', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'Burgwallen-Oude Zijde (00)', 'Burgwallen-Oude Zijde', 'A00', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'Centrum-West (DX01)', 'DX01', 'Centrum-West', 'gebieden', None, 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'Centrum (A)', 'A', 'Centrum', 'gebieden', 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'Amsterdam', '3594', 'bag', 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/', 'YA26', '03630012100692', 'gebieden', 'Point', 121421.0, 487278.0, 'bag'])
# dict_values(['https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076982/', 'Damstraat 2-HR', '03630000076982', '0363200000076982', '2018-08-22T23:14:09.272367Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', '16', 'Naamgeving uitgegeven', None, 'Damstraat 2-HR', '1012JM', 2, '', 'HR', 'Verblijfsobject', '', 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'Damstraat', '0363300000003189', 'bag', True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614785/', 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'Nes e.o. (A00d)', '00d', 'Nes e.o.', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'Burgwallen-Oude Zijde (00)', 'Burgwallen-Oude Zijde', 'A00', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'Centrum-West (DX01)', 'DX01', 'Centrum-West', 'gebieden', None, 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'Centrum (A)', 'A', 'Centrum', 'gebieden', 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'Amsterdam', '3594', 'bag', 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/', 'YA26', '03630012100692', 'gebieden', 'Point', 121421.0, 487278.0, 'bag'])
# dict_values(['https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076985/', 'Damstraat 2A', '03630000076985', '0363200000076985', '2018-08-22T23:05:14.573148Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', '16', 'Naamgeving uitgegeven', None, 'Damstraat 2A', '1012JM', 2, 'A', '', 'Verblijfsobject', '', 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'Damstraat', '0363300000003189', 'bag', True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614787/', 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'Nes e.o. (A00d)', '00d', 'Nes e.o.', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'Burgwallen-Oude Zijde (00)', 'Burgwallen-Oude Zijde', 'A00', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'Centrum-West (DX01)', 'DX01', 'Centrum-West', 'gebieden', None, 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'Centrum (A)', 'A', 'Centrum', 'gebieden', 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'Amsterdam', '3594', 'bag', 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/', 'YA26', '03630012100692', 'gebieden', 'Point', 121423.0, 487276.0, 'bag'])
# dict_values(['https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076986/', 'Damstraat 3', '03630000076986', '0363200000076986', '2018-08-22T23:02:15.063193Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', '16', 'Naamgeving uitgegeven', None, 'Damstraat 3', '1012JL', 3, '', '', 'Verblijfsobject', '', 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'Damstraat', '0363300000003189', 'bag', True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614788/', 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/', 'Oude Kerk e.o. (A00b)', '00b', 'Oude Kerk e.o.', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'Burgwallen-Oude Zijde (00)', 'Burgwallen-Oude Zijde', 'A00', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'Centrum-West (DX01)', 'DX01', 'Centrum-West', 'gebieden', None, 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'Centrum (A)', 'A', 'Centrum', 'gebieden', 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'Amsterdam', '3594', 'bag', 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012095692/', 'YA23', '03630012095692', 'gebieden', 'Point', 121445.0, 487283.0, 'bag'])
# dict_values(['https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076987/', 'Damstraat 4', '03630000076987', '0363200000076987', '2018-08-22T23:08:11.449480Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', '16', 'Naamgeving uitgegeven', None, 'Damstraat 4', '1012JM', 4, '', '', 'Verblijfsobject', '', 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'Damstraat', '0363300000003189', 'bag', True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614789/', 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'Nes e.o. (A00d)', '00d', 'Nes e.o.', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'Burgwallen-Oude Zijde (00)', 'Burgwallen-Oude Zijde', 'A00', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'Centrum-West (DX01)', 'DX01', 'Centrum-West', 'gebieden', None, 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'Centrum (A)', 'A', 'Centrum', 'gebieden', 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'Amsterdam', '3594', 'bag', 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/', 'YA26', '03630012100692', 'gebieden', 'Point', 121428.0, 487272.0, 'bag'])
# dict_values(['https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076988/', 'Damstraat 5', '03630000076988', '0363200000076988', '2018-08-22T23:02:15.065902Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', '16', 'Naamgeving uitgegeven', None, 'Damstraat 5', '1012JL', 5, '', '', 'Verblijfsobject', '', 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'Damstraat', '0363300000003189', 'bag', True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614790/', 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/', 'Oude Kerk e.o. (A00b)', '00b', 'Oude Kerk e.o.', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'Burgwallen-Oude Zijde (00)', 'Burgwallen-Oude Zijde', 'A00', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'Centrum-West (DX01)', 'DX01', 'Centrum-West', 'gebieden', None, 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'Centrum (A)', 'A', 'Centrum', 'gebieden', 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'Amsterdam', '3594', 'bag', 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012095692/', 'YA23', '03630012095692', 'gebieden', 'Point', 121454.0, 487278.0, 'bag'])
# dict_values(['https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076989/', 'Damstraat 6', '03630000076989', '0363200000076989', '2018-08-22T23:02:15.068531Z', '2009-12-07', 'GV00000402', '2009-12-07', None, 'DBI', '16', 'Naamgeving uitgegeven', None, 'Damstraat 6', '1012JM', 6, '', '', 'Verblijfsobject', '', 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'Damstraat', '0363300000003189', 'bag', True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614791/', 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'Nes e.o. (A00d)', '00d', 'Nes e.o.', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'Burgwallen-Oude Zijde (00)', 'Burgwallen-Oude Zijde', 'A00', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'Centrum-West (DX01)', 'DX01', 'Centrum-West', 'gebieden', None, 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'Centrum (A)', 'A', 'Centrum', 'gebieden', 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'Amsterdam', '3594', 'bag', 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/', 'YA26', '03630012100692', 'gebieden', 'Point', 121431.0, 487271.0, 'bag'])
# dict_values(['https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076990/', 'Damstraat 7', '03630000076990', '0363200000076990', '2018-08-22T23:05:14.575977Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', '16', 'Naamgeving uitgegeven', None, 'Damstraat 7', '1012JL', 7, '', '', 'Verblijfsobject', '', 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'Damstraat', '0363300000003189', 'bag', True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614792/', 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/', 'Oude Kerk e.o. (A00b)', '00b', 'Oude Kerk e.o.', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'Burgwallen-Oude Zijde (00)', 'Burgwallen-Oude Zijde', 'A00', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'Centrum-West (DX01)', 'DX01', 'Centrum-West', 'gebieden', None, 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'Centrum (A)', 'A', 'Centrum', 'gebieden', 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'Amsterdam', '3594', 'bag', 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012095692/', 'YA23', '03630012095692', 'gebieden', 'Point', 121463.0, 487274.0, 'bag'])
# dict_values(['https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076992/', 'Damstraat 9', '03630000076992', '0363200000076992', '2018-08-22T23:08:11.452084Z', '1980-01-01', 'GV00000402', '1980-01-01', None, 'DBI', '16', 'Naamgeving uitgegeven', None, 'Damstraat 9', '1012JL', 9, '', '', 'Verblijfsobject', '', 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'Damstraat', '0363300000003189', 'bag', True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630001015263/', 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/', 'Oude Kerk e.o. (A00b)', '00b', 'Oude Kerk e.o.', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'Burgwallen-Oude Zijde (00)', 'Burgwallen-Oude Zijde', 'A00', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'Centrum-West (DX01)', 'DX01', 'Centrum-West', 'gebieden', None, 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'Centrum (A)', 'A', 'Centrum', 'gebieden', 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'Amsterdam', '3594', 'bag', 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/', 'YA22', '03630012099548', 'gebieden', 'Point', 121470.0, 487270.0, 'bag'])
# dict_values(['https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076994/', 'Damstraat 11', '03630000076994', '0363200000076994', '2018-08-22T23:08:11.454847Z', '1980-01-01', 'GV00000402', '1980-01-01', None, 'DBI', '16', 'Naamgeving uitgegeven', None, 'Damstraat 11', '1012JL', 11, '', '', 'Verblijfsobject', '', 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'Damstraat', '0363300000003189', 'bag', True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630001015264/', 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/', 'Oude Kerk e.o. (A00b)', '00b', 'Oude Kerk e.o.', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'Burgwallen-Oude Zijde (00)', 'Burgwallen-Oude Zijde', 'A00', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'Centrum-West (DX01)', 'DX01', 'Centrum-West', 'gebieden', None, 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'Centrum (A)', 'A', 'Centrum', 'gebieden', 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'Amsterdam', '3594', 'bag', 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/', 'YA22', '03630012099548', 'gebieden', 'Point', 121475.0, 487267.0, 'bag'])
# dict_values(['https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076995/', 'Damstraat 12', '03630000076995', '0363200000076995', '2018-08-22T23:17:06.864934Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', '16', 'Naamgeving uitgegeven', None, 'Damstraat 12', '1012JM', 12, '', '', 'Verblijfsobject', '', 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'Damstraat', '0363300000003189', 'bag', True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614794/', 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'Nes e.o. (A00d)', '00d', 'Nes e.o.', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'Burgwallen-Oude Zijde (00)', 'Burgwallen-Oude Zijde', 'A00', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'Centrum-West (DX01)', 'DX01', 'Centrum-West', 'gebieden', None, 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'Centrum (A)', 'A', 'Centrum', 'gebieden', 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'Amsterdam', '3594', 'bag', 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/', 'YA26', '03630012100692', 'gebieden', 'Point', 121442.0, 487267.0, 'bag'])
# dict_values(['https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076997/', 'Damstraat 13', '03630000076997', '0363200000076997', '2018-08-22T22:56:03.067623Z', '1980-01-01', 'GV00000402', '1980-01-01', None, 'DBI', '16', 'Naamgeving uitgegeven', None, 'Damstraat 13', '1012JL', 13, '', '', 'Verblijfsobject', '', 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'Damstraat', '0363300000003189', 'bag', True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630001015265/', 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/', 'Oude Kerk e.o. (A00b)', '00b', 'Oude Kerk e.o.', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'Burgwallen-Oude Zijde (00)', 'Burgwallen-Oude Zijde', 'A00', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'Centrum-West (DX01)', 'DX01', 'Centrum-West', 'gebieden', None, 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'Centrum (A)', 'A', 'Centrum', 'gebieden', 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'Amsterdam', '3594', 'bag', 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/', 'YA22', '03630012099548', 'gebieden', 'Point', 121479.0, 487265.0, 'bag'])
# dict_values(['https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000076999/', 'Damstraat 15', '03630000076999', '0363200000076999', '2018-08-22T23:08:11.457705Z', '1980-01-01', 'GV00000402', '1980-01-01', None, 'DBI', '16', 'Naamgeving uitgegeven', None, 'Damstraat 15', '1012JL', 15, '', '', 'Verblijfsobject', '', 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'Damstraat', '0363300000003189', 'bag', True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630001015266/', 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/', 'Oude Kerk e.o. (A00b)', '00b', 'Oude Kerk e.o.', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'Burgwallen-Oude Zijde (00)', 'Burgwallen-Oude Zijde', 'A00', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'Centrum-West (DX01)', 'DX01', 'Centrum-West', 'gebieden', None, 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'Centrum (A)', 'A', 'Centrum', 'gebieden', 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'Amsterdam', '3594', 'bag', 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/', 'YA22', '03630012099548', 'gebieden', 'Point', 121486.0, 487260.0, 'bag'])
# dict_values(['https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077000/', 'Damstraat 16-H', '03630000077000', '0363200000077000', '2018-08-22T23:11:10.391564Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', '16', 'Naamgeving uitgegeven', None, 'Damstraat 16-H', '1012JM', 16, '', 'H', 'Verblijfsobject', '', 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'Damstraat', '0363300000003189', 'bag', True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614802/', 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'Nes e.o. (A00d)', '00d', 'Nes e.o.', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'Burgwallen-Oude Zijde (00)', 'Burgwallen-Oude Zijde', 'A00', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'Centrum-West (DX01)', 'DX01', 'Centrum-West', 'gebieden', None, 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'Centrum (A)', 'A', 'Centrum', 'gebieden', 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'Amsterdam', '3594', 'bag', 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/', 'YA26', '03630012100692', 'gebieden', 'Point', 121451.0, 487261.0, 'bag'])
# dict_values(['https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077002/', 'Damstraat 16-2', '03630000077002', '0363200000077002', '2018-08-22T23:08:11.460416Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', '16', 'Naamgeving uitgegeven', None, 'Damstraat 16-2', '1012JM', 16, '', '2', 'Verblijfsobject', '', 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'Damstraat', '0363300000003189', 'bag', True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614803/', 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'Nes e.o. (A00d)', '00d', 'Nes e.o.', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'Burgwallen-Oude Zijde (00)', 'Burgwallen-Oude Zijde', 'A00', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'Centrum-West (DX01)', 'DX01', 'Centrum-West', 'gebieden', None, 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'Centrum (A)', 'A', 'Centrum', 'gebieden', 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'Amsterdam', '3594', 'bag', 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/', 'YA26', '03630012100692', 'gebieden', 'Point', 121451.0, 487261.0, 'bag'])
# dict_values(['https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077003/', 'Damstraat 16-3', '03630000077003', '0363200000077003', '2018-08-22T23:08:11.463138Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', '16', 'Naamgeving uitgegeven', None, 'Damstraat 16-3', '1012JM', 16, '', '3', 'Verblijfsobject', '', 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'Damstraat', '0363300000003189', 'bag', True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614804/', 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'Nes e.o. (A00d)', '00d', 'Nes e.o.', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'Burgwallen-Oude Zijde (00)', 'Burgwallen-Oude Zijde', 'A00', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'Centrum-West (DX01)', 'DX01', 'Centrum-West', 'gebieden', None, 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'Centrum (A)', 'A', 'Centrum', 'gebieden', 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'Amsterdam', '3594', 'bag', 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/', 'YA26', '03630012100692', 'gebieden', 'Point', 121451.0, 487261.0, 'bag'])
# dict_values(['https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077004/', 'Damstraat 17', '03630000077004', '0363200000077004', '2018-08-22T23:17:06.867798Z', '1980-01-01', 'GV00000402', '1980-01-01', None, 'DBI', '16', 'Naamgeving uitgegeven', None, 'Damstraat 17', '1012JL', 17, '', '', 'Verblijfsobject', '', 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'Damstraat', '0363300000003189', 'bag', True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630001015267/', 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/', 'Oude Kerk e.o. (A00b)', '00b', 'Oude Kerk e.o.', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'Burgwallen-Oude Zijde (00)', 'Burgwallen-Oude Zijde', 'A00', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'Centrum-West (DX01)', 'DX01', 'Centrum-West', 'gebieden', None, 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'Centrum (A)', 'A', 'Centrum', 'gebieden', 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'Amsterdam', '3594', 'bag', 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/', 'YA22', '03630012099548', 'gebieden', 'Point', 121495.0, 487255.0, 'bag'])
# dict_values(['https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077007/', 'Damstraat 19', '03630000077007', '0363200000077007', '2018-08-22T23:14:09.275295Z', '1980-01-01', 'GV00000402', '1980-01-01', None, 'DBI', '16', 'Naamgeving uitgegeven', None, 'Damstraat 19', '1012JL', 19, '', '', 'Verblijfsobject', '', 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'Damstraat', '0363300000003189', 'bag', True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630001015268/', 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/', 'Oude Kerk e.o. (A00b)', '00b', 'Oude Kerk e.o.', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'Burgwallen-Oude Zijde (00)', 'Burgwallen-Oude Zijde', 'A00', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'Centrum-West (DX01)', 'DX01', 'Centrum-West', 'gebieden', None, 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'Centrum (A)', 'A', 'Centrum', 'gebieden', 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'Amsterdam', '3594', 'bag', 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/', 'YA22', '03630012099548', 'gebieden', 'Point', 121499.0, 487254.0, 'bag'])
# dict_values(['https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077008/', 'Damstraat 20', '03630000077008', '0363200000077008', '2018-08-22T23:14:09.277954Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', '16', 'Naamgeving uitgegeven', None, 'Damstraat 20', '1012JM', 20, '', '', 'Verblijfsobject', '', 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'Damstraat', '0363300000003189', 'bag', True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614806/', 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'Nes e.o. (A00d)', '00d', 'Nes e.o.', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'Burgwallen-Oude Zijde (00)', 'Burgwallen-Oude Zijde', 'A00', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'Centrum-West (DX01)', 'DX01', 'Centrum-West', 'gebieden', None, 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'Centrum (A)', 'A', 'Centrum', 'gebieden', 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'Amsterdam', '3594', 'bag', 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012100692/', 'YA26', '03630012100692', 'gebieden', 'Point', 121459.0, 487257.0, 'bag'])
# dict_values(['https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077009/', 'Damstraat 21', '03630000077009', '0363200000077009', '2018-08-22T23:08:11.465954Z', '1980-01-01', 'GV00000402', '1980-01-01', None, 'DBI', '16', 'Naamgeving uitgegeven', None, 'Damstraat 21', '1012JL', 21, '', '', 'Verblijfsobject', '', 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'Damstraat', '0363300000003189', 'bag', True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630001015269/', 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/', 'Oude Kerk e.o. (A00b)', '00b', 'Oude Kerk e.o.', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'Burgwallen-Oude Zijde (00)', 'Burgwallen-Oude Zijde', 'A00', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'Centrum-West (DX01)', 'DX01', 'Centrum-West', 'gebieden', None, 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'Centrum (A)', 'A', 'Centrum', 'gebieden', 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'Amsterdam', '3594', 'bag', 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/', 'YA22', '03630012099548', 'gebieden', 'Point', 121504.0, 487251.0, 'bag'])
# dict_values(['https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077011/', 'Damstraat 23', '03630000077011', '0363200000077011', '2018-08-22T23:02:15.071158Z', '1980-01-01', 'GV00000402', '1980-01-01', None, 'DBI', '16', 'Naamgeving uitgegeven', None, 'Damstraat 23', '1012JL', 23, '', '', 'Verblijfsobject', '', 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'Damstraat', '0363300000003189', 'bag', True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630001015270/', 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/', 'Oude Kerk e.o. (A00b)', '00b', 'Oude Kerk e.o.', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'Burgwallen-Oude Zijde (00)', 'Burgwallen-Oude Zijde', 'A00', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'Centrum-West (DX01)', 'DX01', 'Centrum-West', 'gebieden', None, 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'Centrum (A)', 'A', 'Centrum', 'gebieden', 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'Amsterdam', '3594', 'bag', 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/', 'YA22', '03630012099548', 'gebieden', 'Point', 121507.0, 487250.0, 'bag'])
# dict_values(['https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077013/', 'Damstraat 25', '03630000077013', '0363200000077013', '2018-08-22T23:02:15.073726Z', '1980-01-01', 'GV00000402', '1980-01-01', None, 'DBI', '16', 'Naamgeving uitgegeven', None, 'Damstraat 25', '1012JL', 25, '', '', 'Verblijfsobject', '', 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'Damstraat', '0363300000003189', 'bag', True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630001015271/', 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/', 'Oude Kerk e.o. (A00b)', '00b', 'Oude Kerk e.o.', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'Burgwallen-Oude Zijde (00)', 'Burgwallen-Oude Zijde', 'A00', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'Centrum-West (DX01)', 'DX01', 'Centrum-West', 'gebieden', None, 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'Centrum (A)', 'A', 'Centrum', 'gebieden', 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'Amsterdam', '3594', 'bag', 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/', 'YA22', '03630012099548', 'gebieden', 'Point', 121511.0, 487248.0, 'bag'])
# dict_values(['https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077014/', 'Damstraat 26-H', '03630000077014', '0363200000077014', '2018-08-22T22:58:22.714234Z', '2014-03-15', 'SA00003980_RB02OR', '2014-03-15', None, 'DBI', '16', 'Naamgeving uitgegeven', None, 'Damstraat 26-H', '1012JM', 26, '', 'H', 'Verblijfsobject', '', 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'Damstraat', '0363300000003189', 'bag', True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630011872323/', 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'Nes e.o. (A00d)', '00d', 'Nes e.o.', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'Burgwallen-Oude Zijde (00)', 'Burgwallen-Oude Zijde', 'A00', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'Centrum-West (DX01)', 'DX01', 'Centrum-West', 'gebieden', None, 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'Centrum (A)', 'A', 'Centrum', 'gebieden', 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'Amsterdam', '3594', 'bag', 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099976/', 'YA27', '03630012099976', 'gebieden', 'Point', 121478.0, 487246.0, 'bag'])
# dict_values(['https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077017/', 'Damstraat 26-3', '03630000077017', '0363200000077017', '2018-08-22T23:02:15.076629Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', '16', 'Naamgeving uitgegeven', None, 'Damstraat 26-3', '1012JM', 26, '', '3', 'Verblijfsobject', '', 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'Damstraat', '0363300000003189', 'bag', True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614808/', 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000081/', 'Nes e.o. (A00d)', '00d', 'Nes e.o.', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'Burgwallen-Oude Zijde (00)', 'Burgwallen-Oude Zijde', 'A00', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'Centrum-West (DX01)', 'DX01', 'Centrum-West', 'gebieden', None, 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'Centrum (A)', 'A', 'Centrum', 'gebieden', 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'Amsterdam', '3594', 'bag', 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099976/', 'YA27', '03630012099976', 'gebieden', 'Point', 121478.0, 487246.0, 'bag'])
# dict_values(['https://api.data.amsterdam.nl/bag/nummeraanduiding/0363200000077018/', 'Damstraat 27', '03630000077018', '0363200000077018', '2018-08-22T23:05:14.578694Z', '1005-01-01', 'GV00000402', '1005-01-01', None, 'DBI', '16', 'Naamgeving uitgegeven', None, 'Damstraat 27', '1012JL', 27, '', '', 'Verblijfsobject', '', 'https://api.data.amsterdam.nl/bag/openbareruimte/0363300000003189/', 'Damstraat', '0363300000003189', 'bag', True, None, None, 'https://api.data.amsterdam.nl/bag/verblijfsobject/03630000614809/', 'https://api.data.amsterdam.nl/gebieden/buurt/03630000000079/', 'Oude Kerk e.o. (A00b)', '00b', 'Oude Kerk e.o.', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/buurtcombinatie/3630012052036/', 'Burgwallen-Oude Zijde (00)', 'Burgwallen-Oude Zijde', 'A00', 'gebieden', 'https://api.data.amsterdam.nl/gebieden/gebiedsgerichtwerken/DX01/', 'Centrum-West (DX01)', 'DX01', 'Centrum-West', 'gebieden', None, 'https://api.data.amsterdam.nl/gebieden/stadsdeel/03630000000018/', 'Centrum (A)', 'A', 'Centrum', 'gebieden', 'https://api.data.amsterdam.nl/bag/woonplaats/3594/', 'Amsterdam', '3594', 'bag', 'https://api.data.amsterdam.nl/gebieden/bouwblok/03630012099548/', 'YA22', '03630012099548', 'gebieden', 'Point', 121515.0, 487246.0, 'bag'])
# File saved as: test_flat.csv

# %% [markdown]
# # Nuttige API's en Python functies #
#
# - [Nederlandse BAG zoeker en geosearch](https://github.com/PDOK/locatieserver/wiki/API-Locatieserver)
# - [Werkend voorbeeld van bovenstaande zoeker](https://gist.github.com/Lytrix/948616b492f2da3b7fe758977b459879)
# - [Kenteken data opzoeken op RDW](https://gist.github.com/Lytrix/300b8832086c7b999fb975c1a63c13e7)
# - [Python scripts voor data verwerking](https://github.com/amsterdam/data-processing)
# - [Boilerplate voor Datapunt kaartenlagen in webpagina's](https://github.com/Amsterdam/datapunt_base_layer)

# %% [markdown]
# # Services #
#
# Naast API's zijn er ook Webservices beschikbaar voor geografische informatie op
# https://api.data.amsterdam.nl
#
# Er zijn 3 services beschikbaar
# - **WMS**: bitmaps van kaartlagen om snel in te laden in browsers
# - **WFS**: vectordata van kaartlagen om ruimtelijke berekeningen en eigen styling op toe te passen.
# - **TMS/WMS Tiles**: Kant en klaar gerenderde bitmap tiles voor ieder zoomniveau van de topografie kaartlagen om sneller in te kunnen laden (zelfs op 4 servers tegelijkertijd)

# %% [markdown]
# # Web Feature Services (WFS)#
#
# Deze service is vergelijkbaar met API's maar zijn bedoelt om snel meerdere geografische objecten te kunnen tonen.
#
# API's lenen zich vooral goed om per object detailinformatie op te halen.

# %% [markdown]
# # Web Mapping Service (WMS)#
#
# Deze service is vooral bedoeld om overlay kaarten mee aan te roepen zoals gebieden en luchtfoto's, maar worden ook gebruikt om snel lagen met veel data te kunnen tonen op data.amsterdam.nl zoals parkeervakken. Als je op de kaart klikt selecteer je de URI van de overlay laag en haal je via de API de onderliggende data op.

# %% [markdown]
# #### Webservices in data.amsterdam.nl ####
# Zo wordt dit ook op https://data.amsterdam.nl gebruikt. De WMS laat een platgeslagen PNG zien, en als je erop klikt stuur je de uri door naar de API die detailinformatie voor je ophaalt.
#
# De gegevens komen uit dezelfde onderliggende Database als de API gebruikt, dus ze zijn altijd gelijk aan elkaar.

# %% [markdown]
# #### XML vs JSON ####
# Het bevragingsformaat is anders dan de API in XML. Het bevragen kan je via de url uitvoeren of via XML posts.
#
# Om te zien wat de service aan functies en kaartlagen heeft, kan je opvragen per service:
#
# https://map.data.amsterdam.nl/maps/gebieden?REQUEST=GetCapabilities&SERVICE=wfs

# %% [markdown]
# ### Voorbeelden ###
#
# WFS services hebben veel functionaliteiten. De 3 meest krachtige zijn:
# - Filteren op attribuut
# - Teruggeven van 500.000 objecten in verschillende bestandsformaten
# - Het ruimtelijk selecteren binnen een andere geometrie.

# %% [markdown]
# #### Filter op attribuutnaam ####
#
# Voor de kaart bij bekendmakingen.amsterdam.nl halen we dagelijks de digitale bekendmakingen op vanaf overheid.nl met de filter ingesteld op overheid=Amsterdam
#
# https://www.amsterdam.nl/actueel/bekendmakingen/bekendmakingen-kaart/
#
# ```
# http://geozet.koop.overheid.nl/wfs?REQUEST=GetFeature&SERVICE=WFS&VERSION=1.0.0&TYPENAME=geozet:bekendmakingen_punt&FILTER=<Filter><PropertyIsEqualTo><PropertyName>overheid</PropertyName><Literal>Amsterdam
# </Literal></PropertyIsEqualTo></Filter>
# ```

# %% [markdown]
# #### Bestandsformaten ####
#
# Bulkbestanden
# https://map.data.amsterdam.nl/maps/gebieden?REQUEST=GetFeature&SERVICE=wfs&VERSION=1.1.0&TYPENAME=Stadsdeel&OUTPUTFORMAT=geojson

# %% [markdown]
# #### Ruimtelijke selectie ####
#
# Voor de sportparken applicatie wilden we enkel basisregistraties gebruiken als basis.
#
# Daarvoor hebben we de WFS service gebruikt om de BGT objecten te selecteren binnen ieder Sportpark openbare ruimte vlak:
# https://github.com/Amsterdam/Sportparken/blob/master/update/importsportparken.py#L52

# %% [markdown]
# ### Meer Nuttige Services ###
#
# - Landelijke kaartlagen https://www.pdok.nl/
# - Openstreetmap met krachtige API om mee te selecteren https://overpass-turbo.eu/s/zU1
# - CSV en Postgres Dumps van de Basisregistraties van heel Nederland: http://www.nlextract.nl/download

# %% [markdown]
# ## Tot slot: Een gecombineerde set met alle technologieen ##
#
# #### https://amsterdam.github.io/truck_route_osm_amaps/ ####
# Code:
# https://github.com/Amsterdam/truck_route_osm_amaps
#
# - [nlmaps](https://github.com/amsterdam/amaps) (opensource kaartviewer ontwikkeld ism met Kadaster/PDOK)
# - [Topografie van Datapunt](https://t1.data.amsterdam.nl/topo_rd/15/15137/17281.png)
# - [WMS van gebieden](https://map.data.amsterdam.nl/maps/gebieden?REQUEST=GetCapabilities&VERSION=1.1.0&SERVICE=wms)
# - [Autocomplete API Locatieserver](https://geodata.nationaalgeoregister.nl/locatieserver/v3/suggest?fq=gemeentenaam:amsterdam&) en [Lookup API Locatieserver](https://geodata.nationaalgeoregister.nl/locatieserver/v3/lookup?)
# - [OverPass OSM API](https://overpass-api.de/api/interpreter?data=%2F*%0AVrachtroute%20%3E7%2C5%20ton%0A*%2F%0A%0A%5Bout%3Ajson%5D%3B%0A%0A%28%0A%20%20relation%5Broute%3Dtruck%5D%2852.35337677858021%2C4.868316650390625%2C52.39346332646216%2C4.936208724975586%29%3B%0A%20%20%2F%2F%20way%5Bmaxweight%3D120%5D%2852.35337677858021%2C4.868316650390625%2C52.39346332646216%2C4.936208724975586%29%3B%0A%29%3B%0A%0Aout%20body%3B%0A%3E%3B%0Aout%20skel%20qt%3B) selectie voor type truck die door V&OR is aangevuld op OSM
